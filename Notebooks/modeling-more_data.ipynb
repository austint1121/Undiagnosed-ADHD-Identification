# %% [markdown]
# # Introduction
#
# ADHD is a developmental disorder associated with an ongoing pattern of inattention, hyperactivity, and/or impulsivity.
# The symptoms of ADHD can interfere significantly with an individual’s daily activities and relationships.
# ADHD symptoms begin in childhood [and worsen in the teen years and adulthood](https://www.nimh.nih.gov/health/publications/adhd-what-you-need-to-know#part_6209).
#
# People with ADHD experience an ongoing pattern of the following types of symptoms:
#
# - Inattention–having difficulty paying attention
# - Hyperactivity–having too much energy or moving and talking too much
# - Impulsivity–acting without thinking or having difficulty with self-control
#
# Some people with ADHD mainly have symptoms of inattention. Others mostly have symptoms of hyperactivity-impulsivity.
# Some people have both types of symptoms.
#
# ADHD comes in many forms and severities, and teenagers and adults who are undiagnosed often don't even consider they may
# have ADHD if their symptoms don't perfectly match stereotypes of ADHD in the media.

# %% [markdown]
# ## Problem
#
# As established above, Undiagnosed ADHD can be difficult for those with it. But why is it [so common](https://www.singlecare.com/blog/news/adhd-statistics/#adult-adhd-statistics) for ADHD to go undiagnosed?
#
# Personally, I think this is a multi-pronged issue:
#
# **ADHD is not well understood.**
# ADHD is still a [subject of heavy research](https://www.cdc.gov/ncbddd/adhd/research.html) in the science/medical field. Currently, we do not know what causes ADHD, but we know there is some genetic component involved. There is no blood test or any kind of empirical way to test for ADHD; it can only be diagnosed through observation of its symptoms.
#
# **The way ADHD is Diagnosed.**
# To be diagnosed with ADHD, you would have to specifically bring it up with your doctor; this means that if you don't suspect you have it, you may never bring it up to your doctor on your own. ADHD is diagnosed by a doctor [asking a series of questions](https://www.cdc.gov/ncbddd/adhd/diagnosis.html) relating to long-term behavioral patterns at home, so it would be difficult for a doctor to notice ADHD symptoms during a regular visit.
#
# **The way ADHD is portrayed**
# People with ADHD are typically portrayed as young kids, who are extremely hyper-active and disobedient. However, hyperactivity is only one component of ADHD, and it expresses itself in various ways. Especially as kids grow older, hyperactivity can [look very different](https://www.nytimes.com/2010/12/14/health/14klass.html) from what is portrayed in media/pop culture. This results in individuals rejecting the idea that they, or someone they know, has ADHD because their symptoms don't look like stereotypical ADHD symptoms.
#
# So, is there a solution that can be reliably used that **doesn't require a deep understanding of ADHD**, and could help spread awareness that a person may have ADHD regardless of any **personal** or **societal** bias towards what ADHD looks like?
#
#
# Such a solution would greatly benefit individuals with undiagnosed ADHD, and help push people towards getting a diagnoses. There are lots of "ADHD self-tests" on the internet, but they are questionable at best, and misleading at worst. If our hypothetical solution also used **real data** from those diagnosed with ADHD, it would definitely give it more weight as a solution.
#
# Where human perception fails, a machine can excel. Machine learning is the perfect solution for this kind of problem. An AI **doesn't need a deep understanding** of a subject to recognize underlying patterns, and **it doesn't care** about any personal bias, or what ADHD "should" look like according to society. The nature of machine learning also means it would **need to use real data**, But does a data source like that even exist?

# %% [markdown]
# ## Data
#
# The [NSCH](https://www.census.gov/programs-surveys/nsch/data/datasets.html) is a household survey that produces national and state-level data on the physical and emotional health of children 0 - 17 years old in the United States. Since 2016, the NSCH has been an annual survey. The survey supports national estimates every year and state-level estimates by combining 2 or 3 years of data. In this project I would primarily look at the 2020 data.
#
# The survey collects information related to the health and well-being of children, including access to and use of health care, family interactions, parental health, school and after-school experiences, and neighborhood characteristics. A parent or other adult caregiver with knowledge of the sampled child’s health and health care filled out the topical questionnaire.
#
# Survey topics include:
# - Child and family characteristics
# - **Physical and mental health status, including current conditions and functional difficulties**
# - Health insurance status, type, and adequacy
# - Access and use of health care services
# - Medical, dental, and specialty care needed and received
# - Family health and activities
# - Impact of child’s health on family
# - Neighborhood characteristics

# %% [markdown]
# ## Goal
# In the NSCH data is a question that asks:
# - Has a doctor or other health care provider EVER told you that this child has…
#    Attention Deficit Disorder or Attention-Deficit/Hyperactivity Disorder, that is, ADD or ADHD?
#
# For this project, I'm going create a tool that can give the probability that a child from the survey has ADHD, **but is undiagnosed**.
#
# One distinction I'd like to make: **This project is not about diagnosing kids with ADHD**. Only a trained medical professional can diagnose someone with ADHD. This project and it's results are about spreading awareness.

# %% [markdown]
# ## Exploratory Data Analysis
# The following section is a shortened version of this [notebook](/Notebooks/EDA.ipynb).
#
# Lets investigate and visualize some aspects of our data to help our understanding:
#
# - Distribution of kids Diagnosed with ADHD
# - Distribution of gender/sex among children diagnosed with ADHD
# - Distribution of race/ethnicity of children diagnosed with ADHD
# - Age/age groups of kids diagnosed with ADHD

# %% [markdown]
# ### Loading and Exploring the Data
# Lets first load and explore the data, and confirm its size and shape.

# %%
# Import statements
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Setting Seaborn's visual style
sns.set_style('white')

# %%
# Loading data into pandas dateframe
nsch20 = pd.read_sas('../Data/nsch_2020_topical_SAS/nsch_2020_topical.sas7bdat')
# Joining all the data into one frame, keeping ONLY the columns that are present in all frames.
nsch19 = pd.read_sas('../Data/nsch_2019_topical_SAS/nsch_2019_topical.sas7bdat')
nsch18 = pd.read_sas('../Data/nsch_2018_topical_SAS/nsch_2018_topical.sas7bdat')
nsch = pd.concat([nsch20, nsch19, nsch18], join='inner', ignore_index=True)
# Out:
# /Users/matthewturner/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/pandas/io/sas/sas7bdat.py:800: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   rslt[name] = self._byte_chunk[jb, :].view(dtype=self.byte_order + "d")

# %% [markdown]
# ### Data Shape

# %%
# Getting shape of data frame and assigning to variables
total_rows, total_columns = nsch.shape

print(f'There are {total_rows} completed surveys')
print(f'There are {total_columns} questions in the survey')
# Out:
# There are 102740 completed surveys
# There are 428 questions in the survey

# %% [markdown]
# The [Methodology Report](https://www2.census.gov/programs-surveys/nsch/technical-documentation/methodology/2020-NSCH-Methodology-Report.pdf) for this survey states that they ***reached out to 240,000 house holds, and 93,000 completed a screener survey**.
#
# They also state that **of those 93,000 households, 51,107 are included in the public use file**, however, of the 51,107 households **only 42,777 submitted a complete survey**. So our numbers match up with what is in the report.

# %% [markdown]
# ### ADHD Distribution
#
# Our target column for prediction will be "K2Q31B", which says:
#
#
# > "Does this child CURRENTLY have Attention Deficit Disorder or Attention-Deficit/Hyperactivity Disorder
#
# Lets visualize its distribution.

# %%
nsch['K2Q31B'].isna().value_counts()
replaced_nan = nsch['K2Q31B'].fillna(2)
replaced_nan.value_counts()
# Out:
# 2.0    93415
# 1.0     9325
# Name: K2Q31B, dtype: int64

# %%
# Replacing numbers with words for easier plotting
adhd_yn = replaced_nan.replace({1: 'Yes', 2: 'No'})

# Plotting
fig, ax = plt.subplots(figsize=(8, 6))
adhd_figure = sns.countplot(adhd_yn, ax=ax, edgecolor='black', order=['Yes', 'No'])
plt.suptitle('Has a doctor diagnosed the child with ADHD?')
adhd_figure.set(xlabel='Response')


# Percentages of kids with ADHD
no_adhd_p, yes_adhd_p = adhd_yn.value_counts(normalize=True)

print(f'{no_adhd_p*100:.0f}% of kids in this sample have not been diagnosed ADHD.')
print(f'{yes_adhd_p*100:.0f}% of kids in this sample have been diagnosed ADHD.')
# Out:
# /Users/matthewturner/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 91% of kids in this sample have not been diagnosed ADHD.
# 9% of kids in this sample have been diagnosed ADHD.

# %% [markdown]
# #### Analysis
# It is hard to try and compare this to an overall estimate of ADHD among the overall population, since most studies use this survey as a basis for estimation. It is important to note that kids with special health care needs have been super-sampled when the data was collected. The actual population of kids diagnosed with ADHD, most likely, does not look like this. We have an incredibly small amount of kida actually diagnosed with ADHD, and this lack of data may prove a challenge later when modeling.
#
# Now that we have this information, let's look into these 9325 kids and look at some relationships between other columns

# %% [markdown]
# ### ADHD Diagnoses and Gender
# Lets investigate the relationship between a child's sex and ADHD diagnoses

# %%
# Grab a dataframe with only ADHD diagnosed kids
adhd_df = nsch[nsch['K2Q31B'] == 1]

# Replace numbers with "Male" and "Female" for easier plotting
adhd_df['SC_SEX'] = adhd_df['SC_SEX'].replace({1: 'Male', 2: 'Female'})

# Plotting
sex_fig, sex_ax = plt.subplots(figsize=(8, 6))
adhd_sex_figure = sns.countplot(adhd_df['SC_SEX'], ax=sex_ax, edgecolor='black', order=['Male', 'Female'])
plt.suptitle('Sex of Kids Diagnosed with ADHD')
adhd_sex_figure.set(xlabel='Sex');
# Out:
# /var/folders/y8/vq429chs6djb0hl0y0zp5fg00000gn/T/ipykernel_66263/1265693889.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adhd_df['SC_SEX'] = adhd_df['SC_SEX'].replace({1: 'Male', 2: 'Female'})
# /Users/matthewturner/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Get normalized value counts of Sex
male_p, female_p = adhd_df['SC_SEX'].value_counts(normalize=True)

# Print percentages rounded to the nearest whole number.
print(f' Of all the kids with ADHD in our sample {male_p*100:.0f}% are male, and {female_p*100:.0f}% are female')
# Out:
#  Of all the kids with ADHD in our sample 69% are male, and 31% are female

# %% [markdown]
# ### Analysis
# These results match up with the Census Bueraus findings that males are more likley to be diagnosed with ADHD then females are. ADHD and sex is a subject of ongoing research, and I highly suggest reading [this](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6923191/) study on the subject matter for an in-depth look on the matter.

# %% [markdown]
# ### ADHD and Age
# Now to investigate the ages of those with ADHD.

# %%
# Replacing formtype category names for more readable graphs
adhd_df['FORMTYPE'] = adhd_df['FORMTYPE'].astype('str').replace({"b'T1'": 'Group 1 (0-5)', "b'T2'": 'Group 2 (6-11)', "b'T3'": 'Group 3 (12-17)'})
nsch['FORMTYPE'] = nsch['FORMTYPE'].astype('str').replace({"b'T1'": 'Group 1 (0-5)', "b'T2'": 'Group 2 (6-11)', "b'T3'": 'Group 3 (12-17)'})

# Set figure and axis
agefig, (ageax, realax) = plt.subplots(1, 2, figsize=(18, 10))

# Plot figure with 18 bins (ages go from 1-17) with an extra bin for aesthetic reasons
age_figure = sns.histplot(data=adhd_df, x='SC_AGE_YEARS', ax=ageax, bins=18, hue='FORMTYPE', hue_order=['Group 1 (0-5)', 'Group 2 (6-11)', 'Group 3 (12-17)'])
real_figure = sns.histplot(data=nsch, x='SC_AGE_YEARS', ax=realax, bins=18, hue='FORMTYPE', hue_order=['Group 1 (0-5)', 'Group 2 (6-11)', 'Group 3 (12-17)'])

# Setting labels, title, and ticks.
age_figure.set(title='Ages of Kids Diagnosed with ADHD', xlabel='Age', xticks=list(range(1, 17)))
real_figure.set(title='Ages of All Kids in Sample', xlabel='Age', xticks=list(range(1, 17)));
# Out:
# /var/folders/y8/vq429chs6djb0hl0y0zp5fg00000gn/T/ipykernel_66263/2208899985.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adhd_df['FORMTYPE'] = adhd_df['FORMTYPE'].astype('str').replace({"b'T1'": 'Group 1 (0-5)', "b'T2'": 'Group 2 (6-11)', "b'T3'": 'Group 3 (12-17)'})

# %% [markdown]
# #### Analysis
# The above graphs make sense to me in context of our data, ADHD is more easily noticeable as children are asked to perform more complex tasks in school. Though it will be important to remember that the resulting model will have a harder time with children in group 1 since there are far less of them.

# %% [markdown]
# ### Racial Distribution of ADHD Diagnoses

# %%
# Replacing formtype category names for more readable graphs
adhd_df['SC_RACE_R'] = adhd_df['SC_RACE_R'].replace({ 1: 'White', 2: 'Black', 3: 'Native Amer.', 4: 'Asian', 5:'Hawaiian', 6:'Other',  7: 'Mixed'})
nsch['SC_RACE_R'] = nsch['SC_RACE_R'].replace({ 1: 'White', 2: 'Black', 3: 'Native Amer.', 4: 'Asian', 5:'Hawaiian', 6:'Other', 7: 'Mixed'})

# Creating figure and axes
racefig, (adhd_race_ax, sample_race_ax) = plt.subplots(1, 2, figsize=(18, 10))

# Plotting racial distribution of kids diagnosed with ADHD
adhd_race_figure = sns.histplot(adhd_df, x='SC_RACE_R', ax=adhd_race_ax, edgecolor='black')

# Setting xlabel and title
adhd_race_figure.set(xlabel='Race of Child', title='Race Distribution of Children Diagnosed ADHD')

# Plotting racial distribution of sample
sample_race_figure = sns.histplot(nsch, x='SC_RACE_R', ax=sample_race_ax, color='orange', edgecolor='black')

# Setting xlabel and title
sample_race_figure.set(xlabel='Race of Child', title='Race Distribution of All Children in Sample');
# Out:
# /var/folders/y8/vq429chs6djb0hl0y0zp5fg00000gn/T/ipykernel_66263/2429262919.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adhd_df['SC_RACE_R'] = adhd_df['SC_RACE_R'].replace({ 1: 'White', 2: 'Black', 3: 'Native Amer.', 4: 'Asian', 5:'Hawaiian', 6:'Other',  7: 'Mixed'})

# %% [markdown]
# #### Analysis
# The distributions seem to match except for one small quirk, there are only about half the amount of asian kids we would expect. I will refrain from simply guessing why this could be, but it will be important to note this aspect of the data. It is also important to note that the distribution of our overall data does not match the [overall estimates](https://www.census.gov/quickfacts/fact/table/US/PST045219) for the United States. This will be another limitation of my data.

# %% [markdown]
# ### EDA Summary
#
# The limitations of this data are:
#
# There are **9325 children** in this sample have been **diagnosed** with ADHD.
# <br>
#
# **9%** of kids in this sample have been **diagnosed** ADHD.
# <br>
#
# Of these kids, **69% are male**, and **31% are female**
# <br>
#
# of the kids diagnosed with ADHD,
#    - **61%** are between the ages of **12-17**
#    - **36%** are between the ages of **6-11**
#    - **3%** are between the ages of **0-5**
#
# The Racial/Ethnic distribution of children with ADHD is:
#
# | Race        | Percentage  |
# | ----------- | ----------- |
# | White       | 81%         |
# | Black       | 8%          |
# | Asian       | 2%          |
# | Mixed       | 8%          |
# | Native Am.  | 0.009%      |
# | Hawaiian    | 0.003%      |
# | Other       | 0.004%      |
#
# <br>
#
# #### Why These Things Matter
# This data is important, because my model is only as good as my data. These are some clear, defined limitations of my data. When modeling it will be important to remember that my model will be good at diagnosing white males between the ages of 12-17. This is because that is what I have the most data for. My model may struggle to correctly classify female, or non-white kids when it comes to ADHD. It's important to be transparent about these things, and also to remember that using the data as it is will mean reinforcing any bias that is already present in the data.

# %% [markdown]
# # Data Cleaning
# Data file can specifically be found [here](https://www.census.gov/programs-surveys/nsch/data/datasets.html)
#
# To prepare the data for cleaning I will:
# - Remove columns related to ADHD
# - Ensure all NaN values present in the dataset are addressed
# - Perform a train-test split on the data and create a holdout set as well.
# - Save transformed/cleaned data as CSV files.
#
# The full cleaning notebook can be found [here](/Notebooks/Data_Cleaning.ipynb)

# %%
# Imports for this section
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
# Loading data into pandas dateframe
nsch = pd.read_sas('../Data/nsch_2020_topical_SAS/nsch_2020_topical.sas7bdat')
# Visually checking successful loading of dataframe
nsch.head()
# Out:
# /Users/matthewturner/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/pandas/io/sas/sas7bdat.py:800: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   rslt[name] = self._byte_chunk[jb, :].view(dtype=self.byte_order + "d")
#   FIPSST STRATUM         HHID FORMTYPE  TOTKIDS_R  TENURE  HHLANGUAGE  \
# 0  b'17'    b'1'  b'20000003'    b'T1'        2.0     1.0         1.0
# 1  b'29'   b'2A'  b'20000004'    b'T3'        1.0     1.0         1.0
# 2  b'47'    b'1'  b'20000005'    b'T1'        1.0     1.0         1.0
# 3  b'28'    b'1'  b'20000014'    b'T3'        2.0     1.0         1.0
# 4  b'55'    b'1'  b'20000015'    b'T3'        2.0     2.0         1.0
#
#    SC_AGE_YEARS  SC_SEX  K2Q35A_1_YEARS  ...  A1_GRADE_IF  BMICLASS  \
# 0           3.0     1.0             NaN  ...          0.0       NaN
# 1          14.0     2.0             NaN  ...          0.0       2.0
# 2           1.0     2.0             NaN  ...          0.0       NaN
# 3          15.0     2.0             NaN  ...          0.0       2.0
# 4          16.0     2.0             NaN  ...          0.0       3.0
#
#    HHCOUNT_IF  FPL_I1  FPL_I2  FPL_I3  FPL_I4  FPL_I5  FPL_I6          FWC
# 0         0.0   400.0   400.0   400.0   400.0   400.0   400.0  3296.080092
# 1         0.0   400.0   400.0   400.0   400.0   400.0   400.0  2888.545330
# 2         0.0   400.0   400.0   400.0   400.0   400.0   400.0  1016.682730
# 3         0.0   143.0   143.0   143.0   143.0   143.0   143.0  1042.091065
# 4         0.0   400.0   400.0   400.0   400.0   400.0   400.0   402.372392
#
# [5 rows x 428 columns]

# %% [markdown]
# ## ADHD Columns
#
# Along with our target column, 'K2Q31A' there are multiple other columns that relate to ADHD that need to be removed. These columns are closely tied to ADHD so they need to be removed so the model doesn't take them into account when making predictions. Column descriptions can be found in the [EDA notebook](https://github.com/austint1121/Undiagnosed-ADHD-Identification/blob/main/Notebooks/EDA.ipynb). We will also save our target column, and remove any rows with null values in that column

# %%
# Creating list of columns to be dropped
related_ADHD = [
    'K2Q31A',
    'K2Q31B',
    'K2Q31C',
    'K2Q31D',
    'K4Q23',
    'SC_K2Q10',
    'SC_K2Q11',
    'SC_K2Q12',
    'ADDTREAT',
    'SC_CSHCN',
    'SC_K2Q22',
    'SC_K2Q10',
    'K4Q22_R',
    'K6Q15',
    'SC_K2Q20',
    'K4Q36',
    'TOTNONSHCN',
    'K4Q28X04',
]

# Dropping rows with NAN values in target column

# Saving Target column
target = nsch['K2Q31B'].fillna(2)

# Creating new dataframe without columns from above
dropped_adhd = nsch.drop(columns=related_ADHD)

# Confirming expected results
dropped_adhd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102740 entries, 0 to 30529
# Columns: 411 entries, FIPSST to FWC
# dtypes: float64(407), object(4)
# memory usage: 322.9+ MB

# %% [markdown]
# ### Binarizing Target Values
# Currently in our target column a "1" means that the child has been diagnosed with ADHD and a 2 means they haven't been. This will cause problems down the road later, so I'm going to manually replace them with 0's and 1's.

# %%
# Dictionary for replacement
testing = {2: 0, 1: 1}

# Preforming replacement
target = target.replace(testing)

# Visually confirming expected change
target.value_counts()
# Out:
# 0.0    93415
# 1.0     9325
# Name: K2Q31B, dtype: int64

# %% [markdown]
# ### Dropping Object Columns

# %%
# Checking the column types
dropped_adhd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102740 entries, 0 to 30529
# Columns: 411 entries, FIPSST to FWC
# dtypes: float64(407), object(4)
# memory usage: 322.9+ MB

# %%
# We have 422 float64 and 4 object types. Lets investigate those 4 objects
dropped_adhd.select_dtypes('object')
# Out:
#       FIPSST STRATUM         HHID FORMTYPE
# 0      b'17'    b'1'  b'20000003'    b'T1'
# 1      b'29'   b'2A'  b'20000004'    b'T3'
# 2      b'47'    b'1'  b'20000005'    b'T1'
# 3      b'28'    b'1'  b'20000014'    b'T3'
# 4      b'55'    b'1'  b'20000015'    b'T3'
# ...      ...     ...          ...      ...
# 30525  b'33'    b'1'  b'18176000'    b'T2'
# 30526  b'53'    b'1'  b'18176008'    b'T1'
# 30527  b'48'   b'2A'  b'18176020'    b'T2'
# 30528  b'13'   b'2A'  b'18176022'    b'T2'
# 30529  b'46'    b'1'  b'18176036'    b'T1'
#
# [102740 rows x 4 columns]

# %% [markdown]
# **FIPSST** - State FIPS code
# **STRATUM** - Sampling Stratum
# **HHID** - Unique Household ID
# **FORMTYPE** - A proxy for age, kids are given a form base on age ranges (T1: 0-5, T2: 6-11, T3:12-17)
#
# All of these columns can be dropped as they should have an effect on whether a child has ADHD, or they are a proxy for an already present variable.

# %%
# Dropping object columns
dropped_final = dropped_adhd.drop(columns=['FIPSST', 'STRATUM', 'HHID', 'FORMTYPE'])
# Confirming expected column count
dropped_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102740 entries, 0 to 30529
# Columns: 407 entries, TOTKIDS_R to FWC
# dtypes: float64(407)
# memory usage: 319.8 MB

# %% [markdown]
# ## Train Test Split
# Before doing any transformations it will be necessary to perform the train test split beforehand to prevent data leakage.

# %%
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(dropped_final, target, random_state=15, stratify=target)

# Split test into a testing and final holdout/validation set
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, random_state=15, stratify=y_test)

# Printing total rows in each set
print(f'Training set is {len(X_train)} entries')
print(f'Testing set is {len(X_test)} entries')
print(f'Validation set is {len(X_val)} entries')
# Out:
# Training set is 77055 entries
# Testing set is 19263 entries
# Validation set is 6422 entries

# %%
# Printing the amount of kids diagnosed with ADHD in each split
print(f'There are {y_train.value_counts().values[1]} kids with ADHD in the training set')
print(f'There are {y_test.value_counts().values[1]} kids with ADHD in the testing set')
print(f'There are {y_val.value_counts().values[1]} kids with ADHD in the validation set')
# Out:
# There are 6994 kids with ADHD in the training set
# There are 1748 kids with ADHD in the testing set
# There are 583 kids with ADHD in the validation set

# %% [markdown]
# ## Handling Missing Values
# There are multiple strategies to handling missing values, normally I would love to use Sklearns experimental [Iterative Imputer](https://scikit-learn.org/stable/modules/generated/sklearn.impute.IterativeImputer.html) however, in this survey some questions are sub questions of others, and can be left blank as a result of the answer to the parent question.
# <br>
# An example of this is the "ADDTREAT" column we dropped earlier. This column is left blank if "K2Q31A" (our target) is answered "No". Instead, I'll use a simple imputer to fill in the null values with ones that will make it clear to the model that they are null values.

# %%
# Simple Imputer filling values with something that vill obviously be a nan value, in this case, 999
SI_imputer = SimpleImputer(strategy='constant', fill_value=999)
# Fitting the imputer to training data / transforming the training data
transformed_X_train = SI_imputer.fit_transform(X_train, y_train)

# Creating a dataframe and re-adding the column names to the data
transformed_X_train = pd.DataFrame(transformed_X_train, columns=X_train.columns)

# Visually confirming transformation
transformed_X_train.head()
# Out:
#    TOTKIDS_R  TENURE  HHLANGUAGE  SC_AGE_YEARS  SC_SEX  K2Q35A_1_YEARS  \
# 0        2.0     1.0         1.0          15.0     1.0           999.0
# 1        3.0     1.0         1.0          13.0     2.0           999.0
# 2        2.0     1.0         1.0           6.0     2.0           999.0
# 3        1.0     1.0         1.0          11.0     2.0           999.0
# 4        1.0     2.0         1.0           2.0     1.0           999.0
#
#    MOMAGE  K6Q41R_STILL  K6Q42R_NEVER  K6Q43R_NEVER  ...  A1_GRADE_IF  \
# 0    29.0         999.0         999.0         999.0  ...          0.0
# 1    30.0         999.0         999.0         999.0  ...          0.0
# 2    37.0         999.0         999.0         999.0  ...          0.0
# 3    43.0         999.0         999.0         999.0  ...          0.0
# 4    39.0           1.0           1.0           2.0  ...          0.0
#
#    BMICLASS  HHCOUNT_IF  FPL_I1  FPL_I2  FPL_I3  FPL_I4  FPL_I5  FPL_I6  \
# 0       3.0         0.0   216.0   216.0   216.0   216.0   216.0   216.0
# 1       2.0         0.0   400.0   400.0   400.0   400.0   400.0   400.0
# 2     999.0         0.0   400.0   400.0   400.0   400.0   400.0   400.0
# 3       2.0         0.0   400.0   400.0   400.0   400.0   400.0   400.0
# 4     999.0         0.0   364.0   364.0   364.0   364.0   364.0   364.0
#
#            FWC
# 0  9436.319619
# 1  1467.584260
# 2   935.219419
# 3   866.622232
# 4   355.567610
#
# [5 rows x 407 columns]

# %%
# Transforming test and validation set
transformed_X_test = SI_imputer.transform(X_test)

# Creating a dataframe and re-adding the column names to the data
transformed_X_test= pd.DataFrame(transformed_X_test, columns=X_test.columns)

# Transforming Validation set
transformed_X_val = SI_imputer.transform(X_val)

# Creating a dataframe and re-adding the column names to the data
transformed_X_val= pd.DataFrame(transformed_X_val, columns=X_val.columns)

# %% [markdown]
# ## Saving the Clean Data

# %%
# Saving the transformed dataframes

# Training Data
transformed_X_train.to_csv('../Data/train/X_train.csv')
y_train.to_csv('../Data/train/y_train.csv')

# Testing Data
transformed_X_test.to_csv('../Data/test/X_test.csv')
y_test.to_csv('../Data/test/y_test')

# Validation Data
transformed_X_val.to_csv('../Data/val/X_val')
y_val.to_csv('../Data/val/y_val.csv')

# %% [markdown]
# From this point forward, any more cleaning would be model specific. I could also clean the data more to improve the overall quality, but I think this will be a good “baseline” starting point for the modeling process. The next step is to begin the modeling process

# %% [markdown]
# # Modeling
# Now its time to get modeling, I created 3 different types of models: [Sklearn decision tree](Notebooks/Modeling-Decision_Tree.ipynb), [Catboost](Notebooks/Modeling-Catboost.ipynb), and a [Keras neural network](Notebooks/Modeling-Keras.ipynb). To keep this notebook from being too long, I'm only going to go over the process of modeling my [final model](Notebooks/Modeling-Catboost-Tuning.ipynb): Catboost.

# %%
# Importing relevant package for this sections
from catboost import CatBoostClassifier,metrics
from functions import metrics as custom_score
from sklearn.metrics import ConfusionMatrixDisplay
from functions import improvement as custom_change
from imblearn.over_sampling import RandomOverSampler, SMOTEN

# %%
# Load in cleaned data.

# Training Data
X_train = pd.read_csv('../Data/train/X_train.csv', index_col=0)
y_train = pd.read_csv('../Data/train/y_train.csv', index_col=0)

# Testing Data
X_test = pd.read_csv('../Data/test/X_test', index_col=0)
y_test = pd.read_csv('../Data/test/y_test.csv', index_col=0)

# %% [markdown]
# # First Simple Model
# I'll now create a first "simple" model to compare to, and iterate from moving forward. This model will be the simplest model I can make with Catboost; there will be no tuning at all.

# %%
# Setting up the model
model = CatBoostClassifier(
    # Adding Accuracy as a metric
    custom_loss=[metrics.Accuracy()],
    random_seed=15,
    logging_level='Silent'
)
# Fitting the model to training data
model.fit(
    X_train, y_train,
    # Using X/y test as eval set
    eval_set=(X_test, y_test),
    # Plot the learning of the model
    plot=True
);
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %%
# Printing training and testing scores.
print("Training Scores")
custom_score(X_train, y_train, model)
print('\t')
print('Testing Scores')
FSM_results = custom_score(X_test, y_test, model)
# Out:
# Training Scores
# Model Results
# Accuracy: 0.98
# Precision: 0.95
# Recall: 0.78
# F1: 0.86
# ROC AUC: 0.98
#
# Testing Scores
# Model Results
# Accuracy: 0.95
# Precision: 0.76
# Recall: 0.62
# F1: 0.68
# ROC AUC: 0.96

# %%
# Creating a confusion matrix for the base model
base_matrix = ConfusionMatrixDisplay.from_predictions(y_test, model.predict(X_test), display_labels=['Undiagnosed','Diagnosed' ])

# %% [markdown]
# #### Analysis
# Catboost has done quite well for a baseline model! The training set has higher scores then the test set, meaning there is some overfitting occurring here. There is a very large drop in recall between the training and test set.
#
# The model has a precision of 0.74 —in other words, **when it predicts a child is diagnosed with ADHD, it is correct 74% of the time**.
#
# Our model has a recall of 0.56—in other words, **it correctly identifies 56% of all children with ADHD**.
#
# The recall score, in particular needs to be improved. The class imbalance needs to be addressed before tuning. Some options:
#    - Class weights
#    - Over/Undersampling
#    - SMOTE (Make more samples)
#
# Catboost does support class weights, so that will be first since it is the simplest to implement.

# %% [markdown]
# # Addressing Class Imbalance

# %% [markdown]
# ## Catboost - Class Weights

# %%
# Setting up the model
weighted_cat = CatBoostClassifier(
    # Adding Accuracy as a metric
    custom_loss=[metrics.Accuracy(), metrics.Recall(), metrics.Precision()],
    random_seed=15,
    logging_level='Silent',
    # Setting class weights to 'balanced'
    auto_class_weights='Balanced'
)

weighted_cat.fit(
    X_train, y_train,
    # Using X/y test as eval set
    eval_set=(X_test, y_test),
    # Uncomment below line to plot the learning of the model
    # plot=True
);
# Results on test set
weighted_results = custom_score(X_test, y_test, weighted_cat)
# Out:
# Model Results
# Accuracy: 0.90
# Precision: 0.47
# Recall: 0.89
# F1: 0.62
# ROC AUC: 0.96

# %%
# Printing changes between base model and weighted model
custom_change(FSM_results, weighted_results)
# Out:
# Change in Results
# Accuracy        -0.04
# Precision       -0.28
# Recall          +0.30
# F1              -0.02
# ROCAUC          +0.11

# %% [markdown]
# ### Analysis
# Adding the weights flipped our model around, now precision has dropped, and recall has improved significantly. For this project, I’d prefer recall over precision because I don’t want the model to be missing kids that may have, potentially, already been passed over/ignored by doctors. I think the gain in recall and ROC/AUC is well worth the loss of precision, but let’s see the results of the other methods.

# %% [markdown]
# ## Random Oversampling
# I’m going to use the imbalanced-learn library to perform oversampling/ SMOTE techniques.

# %%
# Initiate Over sampler
ros = RandomOverSampler(random_state=15)

# Applying ONLY to training set to prevent data leakage.
X_train_os, y_train_os = ros.fit_resample(X_train, y_train)

# %%
# Setting up the model
over_cat = CatBoostClassifier(
    # Adding Accuracy as a metric
    custom_loss=[metrics.Accuracy(), metrics.Recall(), metrics.Precision()],
    random_seed=15,
    logging_level='Silent',
)

over_cat.fit(
    X_train_os, y_train_os,
    # Using X/y test as eval set
    eval_set=(X_test, y_test),
    # Uncomment below line to plot the learning of the model
    # plot=True
);

# %%
# Printing results on test set
os_results = custom_score(X_test, y_test, over_cat)
# Out:
# Model Results
# Accuracy: 0.93
# Precision: 0.58
# Recall: 0.82
# F1: 0.68
# ROC AUC: 0.96

# %%
# Printing the difference between BASE and os_results
print('Difference between Base model and model with oversampling ')
custom_change(FSM_results, os_results)
# Out:
# Difference between Base model and model with oversampling
# Change in Results
# Accuracy        -0.02
# Precision       -0.18
# Recall          +0.20
# F1              -0.00
# ROCAUC          -0.00

# %%
print('Difference between Weighted model and model with oversampling ')
custom_change(weighted_results, os_results)
# Out:
# Difference between Weighted model and model with oversampling
# Change in Results
# Accuracy        +0.03
# Precision       +0.11
# Recall          -0.08
# F1              +0.06
# ROCAUC          -0.00

# %% [markdown]
# ### Analysis
# This model seems to be a "middle ground" between the weighted model and the base model. Rather then having really high recall or precision, it has a decent score on both, and still manages to maintain a high ROC/AUC score. There is one more technique I'll try before iterating on one of these models

# %% [markdown]
# ## SMOTEN
# I'll be using the SMOTEN variant of SMOTE since it is designed specifically for categorical data.

# %%
# Create SMOTE object
smote = SMOTEN(random_state=15)

# Smite that training data
X_smote, y_smote = smote.fit_resample(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/y8/vq429chs6djb0hl0y0zp5fg00000gn/T/ipykernel_66263/2824597246.py in <module>
#       3
#       4 # Smite that training data
# ----> 5 X_smote, y_smote = smote.fit_resample(X_train, y_train)
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/imblearn/base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = (
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/imblearn/over_sampling/_smote/base.py in _fit_resample(self, X, y)
#     723             X_class = _safe_indexing(X_encoded, target_class_indices)
#     724
# --> 725             X_class_dist = vdm.pairwise(X_class)
#     726             self.nn_k_.fit(X_class_dist)
#     727             # the kneigbors search will include the sample itself which is
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/imblearn/metrics/pairwise.py in pairwise(self, X, Y)
#     198                 proba_feature_Y = proba_feature_X
#     199             distance += (
# --> 200                 distance_matrix(proba_feature_X, proba_feature_Y, p=self.k) ** self.r
#     201             )
#     202         return distance
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/scipy/spatial/kdtree.py in distance_matrix(x, y, p, threshold)
#     923         else:
#     924             for j in range(n):
# --> 925                 result[:,j] = minkowski_distance(x,y[j],p)
#     926         return result
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/scipy/spatial/kdtree.py in minkowski_distance(x, y, p)
#      74     y = np.asarray(y)
#      75     if p == np.inf or p == 1:
# ---> 76         return minkowski_distance_p(x, y, p)
#      77     else:
#      78         return minkowski_distance_p(x, y, p)**(1./p)
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/scipy/spatial/kdtree.py in minkowski_distance_p(x, y, p)
#      47         return np.amax(np.abs(y-x), axis=-1)
#      48     elif p == 1:
# ---> 49         return np.sum(np.abs(y-x), axis=-1)
#      50     else:
#      51         return np.sum(np.abs(y-x)**p, axis=-1)
#
# KeyboardInterrupt:

# %%
# Setting up the model
smote_cat = CatBoostClassifier(
    custom_loss=[metrics.Accuracy(), metrics.Recall(), metrics.Precision()],
    random_seed=15,
    logging_level='Silent',
)

smote_cat.fit(
    X_smote, y_smote,
    # Using X/y test as eval set
    eval_set=(X_test, y_test),
    # Uncomment below line to plot the learning of the model
    # plot=True
);

# %%
# Printing results on test set
smote_results = custom_score(X_test, y_test, smote_cat)

# %%
# Printing the difference between FSM and os_results
print('Difference between Base model and SMOTEN model ')
custom_change(FSM_results, smote_results)
# Out:
# Difference between Base model and SMOTEN model
# Change in Results
# Accuracy        -0.00
# Precision       -0.03
# Recall          +0.03
# F1              +0.01
# ROCAUC          +0.01

# %%
# Compare to Oversampling results
print('Difference between random oversampling model and SMOTEN model')
custom_change(os_results, smote_results)
# Out:
# Difference between random oversampling model and SMOTEN model
# Change in Results
# Accuracy        +0.00
# Precision       +0.09
# Recall          -0.15
# F1              -0.03
# ROCAUC          -0.07

# %% [markdown]
# ## Smote Analysis
# Smote performs slightly worse then both of the other options, in almost every way. It even manages to do worse then our first simple model. it has an advantage in precision when compared to the oversampling model, but I think SMOTEN is struggling with creating survey data.
# # Class Imbalance Analysis
# After checking the three suggested methods: Class weights, oversampling, and SMOTE, I'm going to use **Class weights** since it gave the highest recall results. Now, before starting the process of tuning the model, there's one more thing I'd like to address.

# %% [markdown]
# # Removing Features
# Currently, there are over 400 features in the dataset. While doing exploratory data analysis there were columns I saw that definitely won't have an affect on whether a child has ADHD or not. These irrelevant features are creating additional noise that will reduce the performance of the model. Rather then going through all 400+ features by hand and selecting one's I think are important, I can have Catboost select the most important features.

# %%
from catboost import EFeaturesSelectionAlgorithm
from catboost import EShapCalcType

# Instantiate model for selecting features
feature_model = CatBoostClassifier(iterations=1000, random_seed=15)

# Saves a dictictonary containing the lists of features selected and features removed
summary = feature_model.select_features(
    X_train,
    y_train,
    eval_set=(X_test, y_test),
    features_for_select='0-406', # Feature indices to include in search
    num_features_to_select=250, # Number of features to reduce to.
    steps=3,
    algorithm=EFeaturesSelectionAlgorithm.RecursiveByShapValues,
    shap_calc_type=EShapCalcType.Regular,
    train_final_model=True, # Also train a final model for scoring
    logging='Silent'
)
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# Learning rate set to 0.092672
# Step #1 out of 3
# 0:	learn: 0.5575458	test: 0.5577983	best: 0.5577983 (0)	total: 290ms	remaining: 4m 49s
# 1:	learn: 0.4617570	test: 0.4620661	best: 0.4620661 (1)	total: 422ms	remaining: 3m 30s
# 2:	learn: 0.3807953	test: 0.3810936	best: 0.3810936 (2)	total: 591ms	remaining: 3m 16s
# 3:	learn: 0.3221364	test: 0.3222419	best: 0.3222419 (3)	total: 730ms	remaining: 3m 1s
# 4:	learn: 0.2888319	test: 0.2887751	best: 0.2887751 (4)	total: 849ms	remaining: 2m 48s
# 5:	learn: 0.2589579	test: 0.2586991	best: 0.2586991 (5)	total: 1.01s	remaining: 2m 48s
# 6:	learn: 0.2373759	test: 0.2370525	best: 0.2370525 (6)	total: 1.16s	remaining: 2m 44s
# 7:	learn: 0.2214523	test: 0.2209822	best: 0.2209822 (7)	total: 1.44s	remaining: 2m 58s
# 8:	learn: 0.2099902	test: 0.2094104	best: 0.2094104 (8)	total: 1.68s	remaining: 3m 5s
# 9:	learn: 0.2011101	test: 0.2004664	best: 0.2004664 (9)	total: 1.86s	remaining: 3m 4s
# 10:	learn: 0.1923055	test: 0.1915871	best: 0.1915871 (10)	total: 2.01s	remaining: 3m
# 11:	learn: 0.1860971	test: 0.1851357	best: 0.1851357 (11)	total: 2.12s	remaining: 2m 54s
# 12:	learn: 0.1815071	test: 0.1805971	best: 0.1805971 (12)	total: 2.19s	remaining: 2m 45s
# 13:	learn: 0.1776975	test: 0.1767355	best: 0.1767355 (13)	total: 2.3s	remaining: 2m 41s
# 14:	learn: 0.1748026	test: 0.1737303	best: 0.1737303 (14)	total: 2.41s	remaining: 2m 38s
# 15:	learn: 0.1724842	test: 0.1712107	best: 0.1712107 (15)	total: 2.51s	remaining: 2m 34s
# 16:	learn: 0.1695751	test: 0.1683803	best: 0.1683803 (16)	total: 2.64s	remaining: 2m 32s
# 17:	learn: 0.1675977	test: 0.1663867	best: 0.1663867 (17)	total: 2.74s	remaining: 2m 29s
# 18:	learn: 0.1658126	test: 0.1645632	best: 0.1645632 (18)	total: 2.87s	remaining: 2m 28s
# 19:	learn: 0.1639920	test: 0.1627269	best: 0.1627269 (19)	total: 2.96s	remaining: 2m 24s
# 20:	learn: 0.1627791	test: 0.1615768	best: 0.1615768 (20)	total: 3.09s	remaining: 2m 24s
# 21:	learn: 0.1615970	test: 0.1604169	best: 0.1604169 (21)	total: 3.19s	remaining: 2m 21s
# 22:	learn: 0.1599298	test: 0.1587959	best: 0.1587959 (22)	total: 3.31s	remaining: 2m 20s
# 23:	learn: 0.1590072	test: 0.1578285	best: 0.1578285 (23)	total: 3.38s	remaining: 2m 17s
# 24:	learn: 0.1581775	test: 0.1568730	best: 0.1568730 (24)	total: 3.45s	remaining: 2m 14s
# 25:	learn: 0.1569703	test: 0.1556460	best: 0.1556460 (25)	total: 3.52s	remaining: 2m 11s
# 26:	learn: 0.1562959	test: 0.1549969	best: 0.1549969 (26)	total: 3.58s	remaining: 2m 9s
# 27:	learn: 0.1556714	test: 0.1543504	best: 0.1543504 (27)	total: 3.69s	remaining: 2m 8s
# 28:	learn: 0.1551613	test: 0.1539191	best: 0.1539191 (28)	total: 3.81s	remaining: 2m 7s
# 29:	learn: 0.1543343	test: 0.1531980	best: 0.1531980 (29)	total: 3.89s	remaining: 2m 5s
# 30:	learn: 0.1538571	test: 0.1527630	best: 0.1527630 (30)	total: 3.99s	remaining: 2m 4s
# 31:	learn: 0.1531561	test: 0.1521226	best: 0.1521226 (31)	total: 4.14s	remaining: 2m 5s
# 32:	learn: 0.1525588	test: 0.1515834	best: 0.1515834 (32)	total: 4.22s	remaining: 2m 3s
# 33:	learn: 0.1522125	test: 0.1512359	best: 0.1512359 (33)	total: 4.3s	remaining: 2m 2s
# 34:	learn: 0.1515407	test: 0.1506586	best: 0.1506586 (34)	total: 4.37s	remaining: 2m
# 35:	learn: 0.1510831	test: 0.1502458	best: 0.1502458 (35)	total: 4.44s	remaining: 1m 58s
# 36:	learn: 0.1508256	test: 0.1500601	best: 0.1500601 (36)	total: 4.51s	remaining: 1m 57s
# 37:	learn: 0.1504839	test: 0.1497921	best: 0.1497921 (37)	total: 4.57s	remaining: 1m 55s
# 38:	learn: 0.1501381	test: 0.1495363	best: 0.1495363 (38)	total: 4.63s	remaining: 1m 54s
# 39:	learn: 0.1498008	test: 0.1492798	best: 0.1492798 (39)	total: 4.71s	remaining: 1m 53s
# 40:	learn: 0.1493495	test: 0.1488596	best: 0.1488596 (40)	total: 4.79s	remaining: 1m 52s
# 41:	learn: 0.1489823	test: 0.1485021	best: 0.1485021 (41)	total: 4.9s	remaining: 1m 51s
# 42:	learn: 0.1485888	test: 0.1481799	best: 0.1481799 (42)	total: 5.02s	remaining: 1m 51s
# 43:	learn: 0.1483370	test: 0.1479615	best: 0.1479615 (43)	total: 5.14s	remaining: 1m 51s
# 44:	learn: 0.1480973	test: 0.1477202	best: 0.1477202 (44)	total: 5.25s	remaining: 1m 51s
# 45:	learn: 0.1478360	test: 0.1475362	best: 0.1475362 (45)	total: 5.39s	remaining: 1m 51s
# 46:	learn: 0.1475117	test: 0.1472359	best: 0.1472359 (46)	total: 5.5s	remaining: 1m 51s
# 47:	learn: 0.1473233	test: 0.1471102	best: 0.1471102 (47)	total: 5.57s	remaining: 1m 50s
# 48:	learn: 0.1470837	test: 0.1468905	best: 0.1468905 (48)	total: 5.63s	remaining: 1m 49s
# 49:	learn: 0.1468270	test: 0.1466299	best: 0.1466299 (49)	total: 5.68s	remaining: 1m 47s
# 50:	learn: 0.1465948	test: 0.1464082	best: 0.1464082 (50)	total: 5.77s	remaining: 1m 47s
# 51:	learn: 0.1463397	test: 0.1461729	best: 0.1461729 (51)	total: 5.84s	remaining: 1m 46s
# 52:	learn: 0.1461418	test: 0.1459556	best: 0.1459556 (52)	total: 5.89s	remaining: 1m 45s
# 53:	learn: 0.1458938	test: 0.1457153	best: 0.1457153 (53)	total: 5.96s	remaining: 1m 44s
# 54:	learn: 0.1457121	test: 0.1456260	best: 0.1456260 (54)	total: 6.03s	remaining: 1m 43s
# 55:	learn: 0.1453919	test: 0.1454040	best: 0.1454040 (55)	total: 6.09s	remaining: 1m 42s
# 56:	learn: 0.1451820	test: 0.1453297	best: 0.1453297 (56)	total: 6.17s	remaining: 1m 42s
# 57:	learn: 0.1449986	test: 0.1452028	best: 0.1452028 (57)	total: 6.27s	remaining: 1m 41s
# 58:	learn: 0.1446282	test: 0.1448961	best: 0.1448961 (58)	total: 6.39s	remaining: 1m 42s
# 59:	learn: 0.1444104	test: 0.1447792	best: 0.1447792 (59)	total: 6.45s	remaining: 1m 41s
# 60:	learn: 0.1441699	test: 0.1446132	best: 0.1446132 (60)	total: 6.53s	remaining: 1m 40s
# 61:	learn: 0.1440311	test: 0.1444970	best: 0.1444970 (61)	total: 6.6s	remaining: 1m 39s
# 62:	learn: 0.1438111	test: 0.1443027	best: 0.1443027 (62)	total: 6.67s	remaining: 1m 39s
# 63:	learn: 0.1436547	test: 0.1442208	best: 0.1442208 (63)	total: 6.76s	remaining: 1m 38s
# 64:	learn: 0.1435019	test: 0.1441430	best: 0.1441430 (64)	total: 6.84s	remaining: 1m 38s
# 65:	learn: 0.1432699	test: 0.1439700	best: 0.1439700 (65)	total: 6.9s	remaining: 1m 37s
# 66:	learn: 0.1431031	test: 0.1438788	best: 0.1438788 (66)	total: 6.96s	remaining: 1m 36s
# 67:	learn: 0.1428991	test: 0.1437744	best: 0.1437744 (67)	total: 7.03s	remaining: 1m 36s
# 68:	learn: 0.1427173	test: 0.1436678	best: 0.1436678 (68)	total: 7.09s	remaining: 1m 35s
# 69:	learn: 0.1425567	test: 0.1435895	best: 0.1435895 (69)	total: 7.16s	remaining: 1m 35s
# 70:	learn: 0.1422802	test: 0.1434250	best: 0.1434250 (70)	total: 7.38s	remaining: 1m 36s
# 71:	learn: 0.1420820	test: 0.1433095	best: 0.1433095 (71)	total: 7.48s	remaining: 1m 36s
# 72:	learn: 0.1419590	test: 0.1432796	best: 0.1432796 (72)	total: 7.58s	remaining: 1m 36s
# 73:	learn: 0.1417880	test: 0.1432062	best: 0.1432062 (73)	total: 7.69s	remaining: 1m 36s
# 74:	learn: 0.1416600	test: 0.1431397	best: 0.1431397 (74)	total: 7.81s	remaining: 1m 36s
# 75:	learn: 0.1414597	test: 0.1430363	best: 0.1430363 (75)	total: 8s	remaining: 1m 37s
# 76:	learn: 0.1412700	test: 0.1429258	best: 0.1429258 (76)	total: 8.2s	remaining: 1m 38s
# 77:	learn: 0.1411157	test: 0.1428347	best: 0.1428347 (77)	total: 8.4s	remaining: 1m 39s
# 78:	learn: 0.1408224	test: 0.1426462	best: 0.1426462 (78)	total: 8.63s	remaining: 1m 40s
# 79:	learn: 0.1406493	test: 0.1425676	best: 0.1425676 (79)	total: 8.82s	remaining: 1m 41s
# 80:	learn: 0.1404879	test: 0.1424895	best: 0.1424895 (80)	total: 8.95s	remaining: 1m 41s
# 81:	learn: 0.1403551	test: 0.1424011	best: 0.1424011 (81)	total: 9.03s	remaining: 1m 41s
# 82:	learn: 0.1401806	test: 0.1422395	best: 0.1422395 (82)	total: 9.13s	remaining: 1m 40s
# 83:	learn: 0.1400036	test: 0.1421343	best: 0.1421343 (83)	total: 9.22s	remaining: 1m 40s
# 84:	learn: 0.1398603	test: 0.1420684	best: 0.1420684 (84)	total: 9.33s	remaining: 1m 40s
# 85:	learn: 0.1396706	test: 0.1419849	best: 0.1419849 (85)	total: 9.43s	remaining: 1m 40s
# 86:	learn: 0.1394409	test: 0.1417983	best: 0.1417983 (86)	total: 9.52s	remaining: 1m 39s
# 87:	learn: 0.1392983	test: 0.1417358	best: 0.1417358 (87)	total: 9.84s	remaining: 1m 41s
# 88:	learn: 0.1390856	test: 0.1416222	best: 0.1416222 (88)	total: 10s	remaining: 1m 42s
# 89:	learn: 0.1389497	test: 0.1415589	best: 0.1415589 (89)	total: 10.2s	remaining: 1m 43s
# 90:	learn: 0.1388175	test: 0.1415535	best: 0.1415535 (90)	total: 10.3s	remaining: 1m 43s
# 91:	learn: 0.1386678	test: 0.1414767	best: 0.1414767 (91)	total: 10.5s	remaining: 1m 43s
# 92:	learn: 0.1384920	test: 0.1413349	best: 0.1413349 (92)	total: 10.6s	remaining: 1m 42s
# 93:	learn: 0.1383585	test: 0.1412689	best: 0.1412689 (93)	total: 10.8s	remaining: 1m 44s
# 94:	learn: 0.1381682	test: 0.1411044	best: 0.1411044 (94)	total: 10.9s	remaining: 1m 43s
# 95:	learn: 0.1379905	test: 0.1410456	best: 0.1410456 (95)	total: 11s	remaining: 1m 43s
# 96:	learn: 0.1377496	test: 0.1408817	best: 0.1408817 (96)	total: 11.1s	remaining: 1m 43s
# 97:	learn: 0.1375885	test: 0.1408010	best: 0.1408010 (97)	total: 11.2s	remaining: 1m 43s
# 98:	learn: 0.1374269	test: 0.1406860	best: 0.1406860 (98)	total: 11.4s	remaining: 1m 43s
# 99:	learn: 0.1372807	test: 0.1406287	best: 0.1406287 (99)	total: 11.6s	remaining: 1m 44s
# 100:	learn: 0.1370818	test: 0.1405207	best: 0.1405207 (100)	total: 11.7s	remaining: 1m 44s
# 101:	learn: 0.1369013	test: 0.1403493	best: 0.1403493 (101)	total: 11.8s	remaining: 1m 43s
# 102:	learn: 0.1367957	test: 0.1403745	best: 0.1403493 (101)	total: 11.9s	remaining: 1m 43s
# 103:	learn: 0.1366816	test: 0.1403228	best: 0.1403228 (103)	total: 12s	remaining: 1m 43s
# 104:	learn: 0.1365552	test: 0.1402891	best: 0.1402891 (104)	total: 12.1s	remaining: 1m 42s
# 105:	learn: 0.1364018	test: 0.1402358	best: 0.1402358 (105)	total: 12.2s	remaining: 1m 42s
# 106:	learn: 0.1362639	test: 0.1401799	best: 0.1401799 (106)	total: 12.2s	remaining: 1m 42s
# 107:	learn: 0.1361105	test: 0.1401042	best: 0.1401042 (107)	total: 12.3s	remaining: 1m 41s
# 108:	learn: 0.1359501	test: 0.1400502	best: 0.1400502 (108)	total: 12.3s	remaining: 1m 40s
# 109:	learn: 0.1358344	test: 0.1400034	best: 0.1400034 (109)	total: 12.4s	remaining: 1m 40s
# 110:	learn: 0.1356947	test: 0.1399264	best: 0.1399264 (110)	total: 12.5s	remaining: 1m 39s
# 111:	learn: 0.1355658	test: 0.1398852	best: 0.1398852 (111)	total: 12.5s	remaining: 1m 39s
# 112:	learn: 0.1353860	test: 0.1397748	best: 0.1397748 (112)	total: 12.6s	remaining: 1m 38s
# 113:	learn: 0.1352283	test: 0.1397366	best: 0.1397366 (113)	total: 12.7s	remaining: 1m 38s
# 114:	learn: 0.1351137	test: 0.1397025	best: 0.1397025 (114)	total: 12.7s	remaining: 1m 37s
# 115:	learn: 0.1350027	test: 0.1396649	best: 0.1396649 (115)	total: 12.8s	remaining: 1m 37s
# 116:	learn: 0.1348293	test: 0.1396070	best: 0.1396070 (116)	total: 12.8s	remaining: 1m 36s
# 117:	learn: 0.1347032	test: 0.1396652	best: 0.1396070 (116)	total: 12.9s	remaining: 1m 36s
# 118:	learn: 0.1345419	test: 0.1396141	best: 0.1396070 (116)	total: 12.9s	remaining: 1m 35s
# 119:	learn: 0.1343165	test: 0.1394827	best: 0.1394827 (119)	total: 13s	remaining: 1m 35s
# 120:	learn: 0.1341818	test: 0.1395072	best: 0.1394827 (119)	total: 13s	remaining: 1m 34s
# 121:	learn: 0.1340060	test: 0.1394711	best: 0.1394711 (121)	total: 13.1s	remaining: 1m 34s
# 122:	learn: 0.1338303	test: 0.1393809	best: 0.1393809 (122)	total: 13.2s	remaining: 1m 33s
# 123:	learn: 0.1337272	test: 0.1393215	best: 0.1393215 (123)	total: 13.4s	remaining: 1m 34s
# 124:	learn: 0.1336219	test: 0.1392537	best: 0.1392537 (124)	total: 13.5s	remaining: 1m 34s
# 125:	learn: 0.1334584	test: 0.1391572	best: 0.1391572 (125)	total: 13.5s	remaining: 1m 33s
# 126:	learn: 0.1332933	test: 0.1391193	best: 0.1391193 (126)	total: 13.6s	remaining: 1m 33s
# 127:	learn: 0.1331497	test: 0.1390676	best: 0.1390676 (127)	total: 13.7s	remaining: 1m 33s
# 128:	learn: 0.1330325	test: 0.1390680	best: 0.1390676 (127)	total: 13.7s	remaining: 1m 32s
# 129:	learn: 0.1328842	test: 0.1390329	best: 0.1390329 (129)	total: 13.8s	remaining: 1m 32s
# 130:	learn: 0.1326790	test: 0.1388728	best: 0.1388728 (130)	total: 13.8s	remaining: 1m 31s
# 131:	learn: 0.1325210	test: 0.1388573	best: 0.1388573 (131)	total: 13.9s	remaining: 1m 31s
# 132:	learn: 0.1323584	test: 0.1387904	best: 0.1387904 (132)	total: 14s	remaining: 1m 31s
# 133:	learn: 0.1322244	test: 0.1387615	best: 0.1387615 (133)	total: 14s	remaining: 1m 30s
# 134:	learn: 0.1321424	test: 0.1387303	best: 0.1387303 (134)	total: 14.1s	remaining: 1m 30s
# 135:	learn: 0.1320089	test: 0.1387175	best: 0.1387175 (135)	total: 14.2s	remaining: 1m 29s
# 136:	learn: 0.1318463	test: 0.1386141	best: 0.1386141 (136)	total: 14.2s	remaining: 1m 29s
# 137:	learn: 0.1317573	test: 0.1385915	best: 0.1385915 (137)	total: 14.3s	remaining: 1m 29s
# 138:	learn: 0.1315907	test: 0.1384472	best: 0.1384472 (138)	total: 14.3s	remaining: 1m 28s
# 139:	learn: 0.1314287	test: 0.1384112	best: 0.1384112 (139)	total: 14.4s	remaining: 1m 28s
# 140:	learn: 0.1311943	test: 0.1381734	best: 0.1381734 (140)	total: 14.5s	remaining: 1m 28s
# 141:	learn: 0.1310595	test: 0.1381424	best: 0.1381424 (141)	total: 14.5s	remaining: 1m 27s
# 142:	learn: 0.1309090	test: 0.1381136	best: 0.1381136 (142)	total: 14.6s	remaining: 1m 27s
# 143:	learn: 0.1307504	test: 0.1380927	best: 0.1380927 (143)	total: 14.7s	remaining: 1m 27s
# 144:	learn: 0.1306191	test: 0.1380571	best: 0.1380571 (144)	total: 14.7s	remaining: 1m 26s
# 145:	learn: 0.1305066	test: 0.1379846	best: 0.1379846 (145)	total: 14.8s	remaining: 1m 26s
# 146:	learn: 0.1303739	test: 0.1379617	best: 0.1379617 (146)	total: 14.8s	remaining: 1m 26s
# 147:	learn: 0.1302510	test: 0.1378912	best: 0.1378912 (147)	total: 14.9s	remaining: 1m 25s
# 148:	learn: 0.1301322	test: 0.1378883	best: 0.1378883 (148)	total: 14.9s	remaining: 1m 25s
# 149:	learn: 0.1299664	test: 0.1378375	best: 0.1378375 (149)	total: 15.1s	remaining: 1m 25s
# 150:	learn: 0.1298241	test: 0.1378343	best: 0.1378343 (150)	total: 15.2s	remaining: 1m 25s
# 151:	learn: 0.1296794	test: 0.1377751	best: 0.1377751 (151)	total: 15.2s	remaining: 1m 24s
# 152:	learn: 0.1294311	test: 0.1376252	best: 0.1376252 (152)	total: 15.3s	remaining: 1m 24s
# 153:	learn: 0.1292591	test: 0.1375399	best: 0.1375399 (153)	total: 15.4s	remaining: 1m 24s
# 154:	learn: 0.1291391	test: 0.1375281	best: 0.1375281 (154)	total: 15.6s	remaining: 1m 24s
# 155:	learn: 0.1290278	test: 0.1374851	best: 0.1374851 (155)	total: 15.7s	remaining: 1m 24s
# 156:	learn: 0.1288777	test: 0.1375153	best: 0.1374851 (155)	total: 15.8s	remaining: 1m 24s
# 157:	learn: 0.1287233	test: 0.1375051	best: 0.1374851 (155)	total: 15.9s	remaining: 1m 24s
# 158:	learn: 0.1285941	test: 0.1374375	best: 0.1374375 (158)	total: 16s	remaining: 1m 24s
# 159:	learn: 0.1284865	test: 0.1373818	best: 0.1373818 (159)	total: 16.1s	remaining: 1m 24s
# 160:	learn: 0.1283911	test: 0.1373632	best: 0.1373632 (160)	total: 16.3s	remaining: 1m 24s
# 161:	learn: 0.1282734	test: 0.1373312	best: 0.1373312 (161)	total: 16.5s	remaining: 1m 25s
# 162:	learn: 0.1281678	test: 0.1373581	best: 0.1373312 (161)	total: 16.6s	remaining: 1m 25s
# 163:	learn: 0.1280281	test: 0.1373630	best: 0.1373312 (161)	total: 16.8s	remaining: 1m 25s
# 164:	learn: 0.1279142	test: 0.1373701	best: 0.1373312 (161)	total: 17.1s	remaining: 1m 26s
# 165:	learn: 0.1277704	test: 0.1373192	best: 0.1373192 (165)	total: 17.6s	remaining: 1m 28s
# 166:	learn: 0.1276185	test: 0.1373076	best: 0.1373076 (166)	total: 17.9s	remaining: 1m 29s
# 167:	learn: 0.1274821	test: 0.1372770	best: 0.1372770 (167)	total: 18.1s	remaining: 1m 29s
# 168:	learn: 0.1273117	test: 0.1371822	best: 0.1371822 (168)	total: 18.2s	remaining: 1m 29s
# 169:	learn: 0.1271637	test: 0.1371669	best: 0.1371669 (169)	total: 18.4s	remaining: 1m 29s
# 170:	learn: 0.1270382	test: 0.1371397	best: 0.1371397 (170)	total: 18.5s	remaining: 1m 29s
# 171:	learn: 0.1268819	test: 0.1370873	best: 0.1370873 (171)	total: 18.6s	remaining: 1m 29s
# 172:	learn: 0.1267703	test: 0.1370592	best: 0.1370592 (172)	total: 18.7s	remaining: 1m 29s
# 173:	learn: 0.1266602	test: 0.1370559	best: 0.1370559 (173)	total: 18.8s	remaining: 1m 29s
# 174:	learn: 0.1265218	test: 0.1370292	best: 0.1370292 (174)	total: 18.9s	remaining: 1m 28s
# 175:	learn: 0.1264144	test: 0.1370125	best: 0.1370125 (175)	total: 18.9s	remaining: 1m 28s
# 176:	learn: 0.1262934	test: 0.1369678	best: 0.1369678 (176)	total: 19.1s	remaining: 1m 28s
# 177:	learn: 0.1261613	test: 0.1368989	best: 0.1368989 (177)	total: 19.2s	remaining: 1m 28s
# 178:	learn: 0.1260475	test: 0.1369053	best: 0.1368989 (177)	total: 19.4s	remaining: 1m 28s
# 179:	learn: 0.1259481	test: 0.1369017	best: 0.1368989 (177)	total: 19.5s	remaining: 1m 28s
# 180:	learn: 0.1258092	test: 0.1368742	best: 0.1368742 (180)	total: 19.7s	remaining: 1m 28s
# 181:	learn: 0.1256759	test: 0.1367841	best: 0.1367841 (181)	total: 19.8s	remaining: 1m 29s
# 182:	learn: 0.1255572	test: 0.1367266	best: 0.1367266 (182)	total: 19.9s	remaining: 1m 28s
# 183:	learn: 0.1253802	test: 0.1366554	best: 0.1366554 (183)	total: 20.1s	remaining: 1m 29s
# 184:	learn: 0.1252917	test: 0.1366054	best: 0.1366054 (184)	total: 20.2s	remaining: 1m 29s
# 185:	learn: 0.1251439	test: 0.1365263	best: 0.1365263 (185)	total: 20.3s	remaining: 1m 28s
# 186:	learn: 0.1249797	test: 0.1364615	best: 0.1364615 (186)	total: 20.4s	remaining: 1m 28s
# 187:	learn: 0.1248381	test: 0.1364888	best: 0.1364615 (186)	total: 20.5s	remaining: 1m 28s
# 188:	learn: 0.1246400	test: 0.1364064	best: 0.1364064 (188)	total: 20.6s	remaining: 1m 28s
# 189:	learn: 0.1245506	test: 0.1363805	best: 0.1363805 (189)	total: 20.7s	remaining: 1m 28s
# 190:	learn: 0.1244031	test: 0.1363163	best: 0.1363163 (190)	total: 20.8s	remaining: 1m 28s
# 191:	learn: 0.1242845	test: 0.1363215	best: 0.1363163 (190)	total: 20.9s	remaining: 1m 27s
# 192:	learn: 0.1241661	test: 0.1362452	best: 0.1362452 (192)	total: 20.9s	remaining: 1m 27s
# 193:	learn: 0.1239968	test: 0.1361078	best: 0.1361078 (193)	total: 21s	remaining: 1m 27s
# 194:	learn: 0.1238586	test: 0.1360572	best: 0.1360572 (194)	total: 21.1s	remaining: 1m 27s
# 195:	learn: 0.1237459	test: 0.1360090	best: 0.1360090 (195)	total: 21.2s	remaining: 1m 26s
# 196:	learn: 0.1236222	test: 0.1359233	best: 0.1359233 (196)	total: 21.2s	remaining: 1m 26s
# 197:	learn: 0.1234798	test: 0.1358768	best: 0.1358768 (197)	total: 21.3s	remaining: 1m 26s
# 198:	learn: 0.1233576	test: 0.1358897	best: 0.1358768 (197)	total: 21.3s	remaining: 1m 25s
# 199:	learn: 0.1232214	test: 0.1358812	best: 0.1358768 (197)	total: 21.4s	remaining: 1m 25s
# 200:	learn: 0.1231312	test: 0.1358385	best: 0.1358385 (200)	total: 21.4s	remaining: 1m 25s
# 201:	learn: 0.1230249	test: 0.1358384	best: 0.1358384 (201)	total: 21.5s	remaining: 1m 24s
# 202:	learn: 0.1229352	test: 0.1358215	best: 0.1358215 (202)	total: 21.6s	remaining: 1m 24s
# 203:	learn: 0.1228232	test: 0.1357966	best: 0.1357966 (203)	total: 21.6s	remaining: 1m 24s
# 204:	learn: 0.1227517	test: 0.1357854	best: 0.1357854 (204)	total: 21.7s	remaining: 1m 23s
# 205:	learn: 0.1226274	test: 0.1357718	best: 0.1357718 (205)	total: 21.7s	remaining: 1m 23s
# 206:	learn: 0.1225644	test: 0.1357605	best: 0.1357605 (206)	total: 21.8s	remaining: 1m 23s
# 207:	learn: 0.1224837	test: 0.1357301	best: 0.1357301 (207)	total: 21.8s	remaining: 1m 23s
# 208:	learn: 0.1223793	test: 0.1357549	best: 0.1357301 (207)	total: 21.9s	remaining: 1m 22s
# 209:	learn: 0.1222714	test: 0.1357403	best: 0.1357301 (207)	total: 21.9s	remaining: 1m 22s
# 210:	learn: 0.1221513	test: 0.1356589	best: 0.1356589 (210)	total: 22s	remaining: 1m 22s
# 211:	learn: 0.1220437	test: 0.1356253	best: 0.1356253 (211)	total: 22.1s	remaining: 1m 21s
# 212:	learn: 0.1219137	test: 0.1355990	best: 0.1355990 (212)	total: 22.1s	remaining: 1m 21s
# 213:	learn: 0.1217333	test: 0.1355379	best: 0.1355379 (213)	total: 22.2s	remaining: 1m 21s
# 214:	learn: 0.1216328	test: 0.1354874	best: 0.1354874 (214)	total: 22.2s	remaining: 1m 21s
# 215:	learn: 0.1215221	test: 0.1355588	best: 0.1354874 (214)	total: 22.3s	remaining: 1m 20s
# 216:	learn: 0.1213677	test: 0.1354488	best: 0.1354488 (216)	total: 22.3s	remaining: 1m 20s
# 217:	learn: 0.1212462	test: 0.1354354	best: 0.1354354 (217)	total: 22.4s	remaining: 1m 20s
# 218:	learn: 0.1211316	test: 0.1354053	best: 0.1354053 (218)	total: 22.4s	remaining: 1m 20s
# 219:	learn: 0.1210095	test: 0.1353068	best: 0.1353068 (219)	total: 22.5s	remaining: 1m 19s
# 220:	learn: 0.1208932	test: 0.1352310	best: 0.1352310 (220)	total: 22.6s	remaining: 1m 19s
# 221:	learn: 0.1207720	test: 0.1352340	best: 0.1352310 (220)	total: 22.6s	remaining: 1m 19s
# 222:	learn: 0.1206937	test: 0.1352098	best: 0.1352098 (222)	total: 22.7s	remaining: 1m 19s
# 223:	learn: 0.1206004	test: 0.1351618	best: 0.1351618 (223)	total: 22.7s	remaining: 1m 18s
# 224:	learn: 0.1205000	test: 0.1351589	best: 0.1351589 (224)	total: 22.8s	remaining: 1m 18s
# 225:	learn: 0.1203888	test: 0.1351616	best: 0.1351589 (224)	total: 22.8s	remaining: 1m 18s
# 226:	learn: 0.1202590	test: 0.1351153	best: 0.1351153 (226)	total: 22.9s	remaining: 1m 17s
# 227:	learn: 0.1201867	test: 0.1351208	best: 0.1351153 (226)	total: 22.9s	remaining: 1m 17s
# 228:	learn: 0.1200812	test: 0.1351326	best: 0.1351153 (226)	total: 23s	remaining: 1m 17s
# 229:	learn: 0.1199588	test: 0.1350928	best: 0.1350928 (229)	total: 23.1s	remaining: 1m 17s
# 230:	learn: 0.1198457	test: 0.1350437	best: 0.1350437 (230)	total: 23.1s	remaining: 1m 16s
# 231:	learn: 0.1197506	test: 0.1350620	best: 0.1350437 (230)	total: 23.2s	remaining: 1m 16s
# 232:	learn: 0.1195808	test: 0.1349618	best: 0.1349618 (232)	total: 23.2s	remaining: 1m 16s
# 233:	learn: 0.1194567	test: 0.1348574	best: 0.1348574 (233)	total: 23.3s	remaining: 1m 16s
# 234:	learn: 0.1193302	test: 0.1348745	best: 0.1348574 (233)	total: 23.3s	remaining: 1m 15s
# 235:	learn: 0.1192068	test: 0.1348421	best: 0.1348421 (235)	total: 23.4s	remaining: 1m 15s
# 236:	learn: 0.1190886	test: 0.1348421	best: 0.1348421 (236)	total: 23.4s	remaining: 1m 15s
# 237:	learn: 0.1190071	test: 0.1348090	best: 0.1348090 (237)	total: 23.5s	remaining: 1m 15s
# 238:	learn: 0.1188974	test: 0.1347969	best: 0.1347969 (238)	total: 23.6s	remaining: 1m 15s
# 239:	learn: 0.1188324	test: 0.1347512	best: 0.1347512 (239)	total: 23.6s	remaining: 1m 14s
# 240:	learn: 0.1187253	test: 0.1347341	best: 0.1347341 (240)	total: 23.7s	remaining: 1m 14s
# 241:	learn: 0.1186205	test: 0.1347716	best: 0.1347341 (240)	total: 23.7s	remaining: 1m 14s
# 242:	learn: 0.1185160	test: 0.1347255	best: 0.1347255 (242)	total: 23.8s	remaining: 1m 14s
# 243:	learn: 0.1184045	test: 0.1347135	best: 0.1347135 (243)	total: 23.8s	remaining: 1m 13s
# 244:	learn: 0.1182916	test: 0.1346953	best: 0.1346953 (244)	total: 23.9s	remaining: 1m 13s
# 245:	learn: 0.1181405	test: 0.1346326	best: 0.1346326 (245)	total: 24s	remaining: 1m 13s
# 246:	learn: 0.1180610	test: 0.1346348	best: 0.1346326 (245)	total: 24s	remaining: 1m 13s
# 247:	learn: 0.1179707	test: 0.1346356	best: 0.1346326 (245)	total: 24.1s	remaining: 1m 13s
# 248:	learn: 0.1178595	test: 0.1346435	best: 0.1346326 (245)	total: 24.1s	remaining: 1m 12s
# 249:	learn: 0.1177489	test: 0.1346471	best: 0.1346326 (245)	total: 24.2s	remaining: 1m 12s
# 250:	learn: 0.1176296	test: 0.1346422	best: 0.1346326 (245)	total: 24.2s	remaining: 1m 12s
# 251:	learn: 0.1175247	test: 0.1346239	best: 0.1346239 (251)	total: 24.3s	remaining: 1m 12s
# 252:	learn: 0.1174266	test: 0.1346454	best: 0.1346239 (251)	total: 24.3s	remaining: 1m 11s
# 253:	learn: 0.1173273	test: 0.1346706	best: 0.1346239 (251)	total: 24.4s	remaining: 1m 11s
# 254:	learn: 0.1172076	test: 0.1346521	best: 0.1346239 (251)	total: 24.4s	remaining: 1m 11s
# 255:	learn: 0.1171189	test: 0.1346819	best: 0.1346239 (251)	total: 24.5s	remaining: 1m 11s
# 256:	learn: 0.1170567	test: 0.1346847	best: 0.1346239 (251)	total: 24.5s	remaining: 1m 10s
# 257:	learn: 0.1169678	test: 0.1346815	best: 0.1346239 (251)	total: 24.6s	remaining: 1m 10s
# 258:	learn: 0.1168591	test: 0.1346821	best: 0.1346239 (251)	total: 24.6s	remaining: 1m 10s
# 259:	learn: 0.1167722	test: 0.1346901	best: 0.1346239 (251)	total: 24.7s	remaining: 1m 10s
# 260:	learn: 0.1167062	test: 0.1347005	best: 0.1346239 (251)	total: 24.7s	remaining: 1m 10s
# 261:	learn: 0.1166222	test: 0.1347099	best: 0.1346239 (251)	total: 24.8s	remaining: 1m 9s
# 262:	learn: 0.1164826	test: 0.1346681	best: 0.1346239 (251)	total: 24.9s	remaining: 1m 9s
# 263:	learn: 0.1163429	test: 0.1346163	best: 0.1346163 (263)	total: 24.9s	remaining: 1m 9s
# 264:	learn: 0.1162325	test: 0.1345950	best: 0.1345950 (264)	total: 25s	remaining: 1m 9s
# 265:	learn: 0.1161376	test: 0.1345507	best: 0.1345507 (265)	total: 25.1s	remaining: 1m 9s
# 266:	learn: 0.1159984	test: 0.1344752	best: 0.1344752 (266)	total: 25.2s	remaining: 1m 9s
# 267:	learn: 0.1159027	test: 0.1344315	best: 0.1344315 (267)	total: 25.3s	remaining: 1m 9s
# 268:	learn: 0.1158047	test: 0.1344602	best: 0.1344315 (267)	total: 25.4s	remaining: 1m 8s
# 269:	learn: 0.1157429	test: 0.1344375	best: 0.1344315 (267)	total: 25.5s	remaining: 1m 8s
# 270:	learn: 0.1156735	test: 0.1344321	best: 0.1344315 (267)	total: 25.6s	remaining: 1m 8s
# 271:	learn: 0.1156067	test: 0.1344407	best: 0.1344315 (267)	total: 25.7s	remaining: 1m 8s
# 272:	learn: 0.1154924	test: 0.1344294	best: 0.1344294 (272)	total: 25.8s	remaining: 1m 8s
# 273:	learn: 0.1153716	test: 0.1344494	best: 0.1344294 (272)	total: 25.8s	remaining: 1m 8s
# 274:	learn: 0.1152034	test: 0.1343470	best: 0.1343470 (274)	total: 25.9s	remaining: 1m 8s
# 275:	learn: 0.1150982	test: 0.1343318	best: 0.1343318 (275)	total: 26.1s	remaining: 1m 8s
# 276:	learn: 0.1149615	test: 0.1343398	best: 0.1343318 (275)	total: 26.3s	remaining: 1m 8s
# 277:	learn: 0.1148556	test: 0.1343314	best: 0.1343314 (277)	total: 26.5s	remaining: 1m 8s
# 278:	learn: 0.1147342	test: 0.1342994	best: 0.1342994 (278)	total: 26.7s	remaining: 1m 8s
# 279:	learn: 0.1146647	test: 0.1342810	best: 0.1342810 (279)	total: 26.7s	remaining: 1m 8s
# 280:	learn: 0.1145610	test: 0.1342322	best: 0.1342322 (280)	total: 26.8s	remaining: 1m 8s
# 281:	learn: 0.1143216	test: 0.1340782	best: 0.1340782 (281)	total: 26.9s	remaining: 1m 8s
# 282:	learn: 0.1142340	test: 0.1340616	best: 0.1340616 (282)	total: 27.2s	remaining: 1m 8s
# 283:	learn: 0.1141472	test: 0.1340407	best: 0.1340407 (283)	total: 27.6s	remaining: 1m 9s
# 284:	learn: 0.1140541	test: 0.1340051	best: 0.1340051 (284)	total: 27.9s	remaining: 1m 10s
# 285:	learn: 0.1139761	test: 0.1340074	best: 0.1340051 (284)	total: 28.3s	remaining: 1m 10s
# 286:	learn: 0.1139301	test: 0.1339925	best: 0.1339925 (286)	total: 28.5s	remaining: 1m 10s
# 287:	learn: 0.1138068	test: 0.1338939	best: 0.1338939 (287)	total: 28.7s	remaining: 1m 11s
# 288:	learn: 0.1137364	test: 0.1339284	best: 0.1338939 (287)	total: 28.8s	remaining: 1m 10s
# 289:	learn: 0.1136414	test: 0.1339354	best: 0.1338939 (287)	total: 28.9s	remaining: 1m 10s
# 290:	learn: 0.1135567	test: 0.1339273	best: 0.1338939 (287)	total: 29.1s	remaining: 1m 10s
# 291:	learn: 0.1134659	test: 0.1339162	best: 0.1338939 (287)	total: 29.2s	remaining: 1m 10s
# 292:	learn: 0.1133766	test: 0.1338614	best: 0.1338614 (292)	total: 29.3s	remaining: 1m 10s
# 293:	learn: 0.1132598	test: 0.1337968	best: 0.1337968 (293)	total: 29.4s	remaining: 1m 10s
# 294:	learn: 0.1131775	test: 0.1338085	best: 0.1337968 (293)	total: 29.5s	remaining: 1m 10s
# 295:	learn: 0.1130774	test: 0.1337665	best: 0.1337665 (295)	total: 29.6s	remaining: 1m 10s
# 296:	learn: 0.1129473	test: 0.1337254	best: 0.1337254 (296)	total: 29.7s	remaining: 1m 10s
# 297:	learn: 0.1128591	test: 0.1337340	best: 0.1337254 (296)	total: 29.8s	remaining: 1m 10s
# 298:	learn: 0.1127684	test: 0.1337104	best: 0.1337104 (298)	total: 29.9s	remaining: 1m 10s
# 299:	learn: 0.1126702	test: 0.1337185	best: 0.1337104 (298)	total: 31.1s	remaining: 1m 12s
# 300:	learn: 0.1126118	test: 0.1337389	best: 0.1337104 (298)	total: 31.3s	remaining: 1m 12s
# 301:	learn: 0.1125635	test: 0.1337501	best: 0.1337104 (298)	total: 31.4s	remaining: 1m 12s
# 302:	learn: 0.1124878	test: 0.1337096	best: 0.1337096 (302)	total: 31.4s	remaining: 1m 12s
# 303:	learn: 0.1123974	test: 0.1336954	best: 0.1336954 (303)	total: 31.6s	remaining: 1m 12s
# 304:	learn: 0.1123103	test: 0.1337134	best: 0.1336954 (303)	total: 31.6s	remaining: 1m 12s
# 305:	learn: 0.1122141	test: 0.1337311	best: 0.1336954 (303)	total: 31.7s	remaining: 1m 11s
# 306:	learn: 0.1120783	test: 0.1336643	best: 0.1336643 (306)	total: 31.8s	remaining: 1m 11s
# 307:	learn: 0.1119417	test: 0.1335908	best: 0.1335908 (307)	total: 31.9s	remaining: 1m 11s
# 308:	learn: 0.1118471	test: 0.1335919	best: 0.1335908 (307)	total: 32s	remaining: 1m 11s
# 309:	learn: 0.1117682	test: 0.1335576	best: 0.1335576 (309)	total: 32s	remaining: 1m 11s
# 310:	learn: 0.1116803	test: 0.1335529	best: 0.1335529 (310)	total: 32.1s	remaining: 1m 11s
# 311:	learn: 0.1116084	test: 0.1335414	best: 0.1335414 (311)	total: 32.2s	remaining: 1m 10s
# 312:	learn: 0.1115449	test: 0.1335444	best: 0.1335414 (311)	total: 32.2s	remaining: 1m 10s
# 313:	learn: 0.1114430	test: 0.1335483	best: 0.1335414 (311)	total: 32.3s	remaining: 1m 10s
# 314:	learn: 0.1113677	test: 0.1335156	best: 0.1335156 (314)	total: 32.4s	remaining: 1m 10s
# 315:	learn: 0.1112944	test: 0.1335140	best: 0.1335140 (315)	total: 32.4s	remaining: 1m 10s
# 316:	learn: 0.1111876	test: 0.1334911	best: 0.1334911 (316)	total: 32.6s	remaining: 1m 10s
# 317:	learn: 0.1110980	test: 0.1334725	best: 0.1334725 (317)	total: 32.7s	remaining: 1m 10s
# 318:	learn: 0.1110030	test: 0.1334849	best: 0.1334725 (317)	total: 32.8s	remaining: 1m 10s
# 319:	learn: 0.1108936	test: 0.1335277	best: 0.1334725 (317)	total: 32.9s	remaining: 1m 9s
# 320:	learn: 0.1108003	test: 0.1334844	best: 0.1334725 (317)	total: 33.1s	remaining: 1m 9s
# 321:	learn: 0.1107045	test: 0.1334880	best: 0.1334725 (317)	total: 33.1s	remaining: 1m 9s
# 322:	learn: 0.1106386	test: 0.1334777	best: 0.1334725 (317)	total: 33.2s	remaining: 1m 9s
# 323:	learn: 0.1105785	test: 0.1334912	best: 0.1334725 (317)	total: 33.2s	remaining: 1m 9s
# 324:	learn: 0.1104945	test: 0.1334891	best: 0.1334725 (317)	total: 33.3s	remaining: 1m 9s
# 325:	learn: 0.1103981	test: 0.1334887	best: 0.1334725 (317)	total: 33.4s	remaining: 1m 9s
# 326:	learn: 0.1102862	test: 0.1334287	best: 0.1334287 (326)	total: 33.5s	remaining: 1m 9s
# 327:	learn: 0.1102174	test: 0.1333946	best: 0.1333946 (327)	total: 33.6s	remaining: 1m 8s
# 328:	learn: 0.1101802	test: 0.1333859	best: 0.1333859 (328)	total: 33.7s	remaining: 1m 8s
# 329:	learn: 0.1101005	test: 0.1333760	best: 0.1333760 (329)	total: 33.7s	remaining: 1m 8s
# 330:	learn: 0.1100304	test: 0.1333415	best: 0.1333415 (330)	total: 33.9s	remaining: 1m 8s
# 331:	learn: 0.1099766	test: 0.1333218	best: 0.1333218 (331)	total: 34s	remaining: 1m 8s
# 332:	learn: 0.1098808	test: 0.1333081	best: 0.1333081 (332)	total: 34.1s	remaining: 1m 8s
# 333:	learn: 0.1097890	test: 0.1333264	best: 0.1333081 (332)	total: 34.1s	remaining: 1m 8s
# 334:	learn: 0.1097191	test: 0.1333228	best: 0.1333081 (332)	total: 34.2s	remaining: 1m 7s
# 335:	learn: 0.1096220	test: 0.1332742	best: 0.1332742 (335)	total: 34.3s	remaining: 1m 7s
# 336:	learn: 0.1095350	test: 0.1332302	best: 0.1332302 (336)	total: 34.4s	remaining: 1m 7s
# 337:	learn: 0.1094560	test: 0.1332281	best: 0.1332281 (337)	total: 34.5s	remaining: 1m 7s
# 338:	learn: 0.1093945	test: 0.1332307	best: 0.1332281 (337)	total: 34.6s	remaining: 1m 7s
# 339:	learn: 0.1093201	test: 0.1332593	best: 0.1332281 (337)	total: 34.6s	remaining: 1m 7s
# 340:	learn: 0.1092610	test: 0.1332699	best: 0.1332281 (337)	total: 34.8s	remaining: 1m 7s
# 341:	learn: 0.1091699	test: 0.1332914	best: 0.1332281 (337)	total: 34.8s	remaining: 1m 7s
# 342:	learn: 0.1090810	test: 0.1332801	best: 0.1332281 (337)	total: 34.9s	remaining: 1m 6s
# 343:	learn: 0.1089771	test: 0.1332575	best: 0.1332281 (337)	total: 35s	remaining: 1m 6s
# 344:	learn: 0.1088895	test: 0.1332721	best: 0.1332281 (337)	total: 35.1s	remaining: 1m 6s
# 345:	learn: 0.1087934	test: 0.1332641	best: 0.1332281 (337)	total: 35.2s	remaining: 1m 6s
# 346:	learn: 0.1087114	test: 0.1332569	best: 0.1332281 (337)	total: 35.3s	remaining: 1m 6s
# 347:	learn: 0.1086165	test: 0.1332684	best: 0.1332281 (337)	total: 35.3s	remaining: 1m 6s
# 348:	learn: 0.1085145	test: 0.1332293	best: 0.1332281 (337)	total: 35.4s	remaining: 1m 6s
# 349:	learn: 0.1084172	test: 0.1331823	best: 0.1331823 (349)	total: 35.5s	remaining: 1m 5s
# 350:	learn: 0.1083204	test: 0.1331688	best: 0.1331688 (350)	total: 35.6s	remaining: 1m 5s
# 351:	learn: 0.1082212	test: 0.1331720	best: 0.1331688 (350)	total: 35.7s	remaining: 1m 5s
# 352:	learn: 0.1081351	test: 0.1331546	best: 0.1331546 (352)	total: 35.7s	remaining: 1m 5s
# 353:	learn: 0.1080698	test: 0.1331198	best: 0.1331198 (353)	total: 35.8s	remaining: 1m 5s
# 354:	learn: 0.1079934	test: 0.1331011	best: 0.1331011 (354)	total: 35.9s	remaining: 1m 5s
# 355:	learn: 0.1079290	test: 0.1330994	best: 0.1330994 (355)	total: 35.9s	remaining: 1m 5s
# 356:	learn: 0.1078369	test: 0.1330828	best: 0.1330828 (356)	total: 36s	remaining: 1m 4s
# 357:	learn: 0.1077314	test: 0.1330729	best: 0.1330729 (357)	total: 36.1s	remaining: 1m 4s
# 358:	learn: 0.1076451	test: 0.1330617	best: 0.1330617 (358)	total: 36.2s	remaining: 1m 4s
# 359:	learn: 0.1075376	test: 0.1331094	best: 0.1330617 (358)	total: 36.3s	remaining: 1m 4s
# 360:	learn: 0.1074179	test: 0.1330959	best: 0.1330617 (358)	total: 36.5s	remaining: 1m 4s
# 361:	learn: 0.1073355	test: 0.1330536	best: 0.1330536 (361)	total: 36.6s	remaining: 1m 4s
# 362:	learn: 0.1072475	test: 0.1329941	best: 0.1329941 (362)	total: 36.7s	remaining: 1m 4s
# 363:	learn: 0.1071813	test: 0.1330024	best: 0.1329941 (362)	total: 36.8s	remaining: 1m 4s
# 364:	learn: 0.1071162	test: 0.1329855	best: 0.1329855 (364)	total: 36.9s	remaining: 1m 4s
# 365:	learn: 0.1070190	test: 0.1329386	best: 0.1329386 (365)	total: 37s	remaining: 1m 4s
# 366:	learn: 0.1069374	test: 0.1329436	best: 0.1329386 (365)	total: 37.2s	remaining: 1m 4s
# 367:	learn: 0.1068674	test: 0.1329790	best: 0.1329386 (365)	total: 37.3s	remaining: 1m 4s
# 368:	learn: 0.1067853	test: 0.1329721	best: 0.1329386 (365)	total: 37.4s	remaining: 1m 3s
# 369:	learn: 0.1067400	test: 0.1329657	best: 0.1329386 (365)	total: 37.5s	remaining: 1m 3s
# 370:	learn: 0.1066589	test: 0.1329710	best: 0.1329386 (365)	total: 37.6s	remaining: 1m 3s
# 371:	learn: 0.1065735	test: 0.1329410	best: 0.1329386 (365)	total: 37.7s	remaining: 1m 3s
# 372:	learn: 0.1064517	test: 0.1329382	best: 0.1329382 (372)	total: 37.8s	remaining: 1m 3s
# 373:	learn: 0.1063559	test: 0.1329280	best: 0.1329280 (373)	total: 38s	remaining: 1m 3s
# 374:	learn: 0.1062688	test: 0.1329419	best: 0.1329280 (373)	total: 38.1s	remaining: 1m 3s
# 375:	learn: 0.1062050	test: 0.1329513	best: 0.1329280 (373)	total: 38.2s	remaining: 1m 3s
# 376:	learn: 0.1061254	test: 0.1329468	best: 0.1329280 (373)	total: 38.3s	remaining: 1m 3s
# 377:	learn: 0.1060799	test: 0.1329224	best: 0.1329224 (377)	total: 38.4s	remaining: 1m 3s
# 378:	learn: 0.1059783	test: 0.1329178	best: 0.1329178 (378)	total: 38.5s	remaining: 1m 3s
# 379:	learn: 0.1059353	test: 0.1329304	best: 0.1329178 (378)	total: 38.6s	remaining: 1m 2s
# 380:	learn: 0.1058723	test: 0.1329550	best: 0.1329178 (378)	total: 38.7s	remaining: 1m 2s
# 381:	learn: 0.1057863	test: 0.1329448	best: 0.1329178 (378)	total: 38.8s	remaining: 1m 2s
# 382:	learn: 0.1057266	test: 0.1329264	best: 0.1329178 (378)	total: 38.9s	remaining: 1m 2s
# 383:	learn: 0.1056630	test: 0.1329638	best: 0.1329178 (378)	total: 39s	remaining: 1m 2s
# 384:	learn: 0.1055441	test: 0.1328938	best: 0.1328938 (384)	total: 39.1s	remaining: 1m 2s
# 385:	learn: 0.1054555	test: 0.1328873	best: 0.1328873 (385)	total: 39.2s	remaining: 1m 2s
# 386:	learn: 0.1053428	test: 0.1329003	best: 0.1328873 (385)	total: 39.4s	remaining: 1m 2s
# 387:	learn: 0.1052741	test: 0.1329000	best: 0.1328873 (385)	total: 39.5s	remaining: 1m 2s
# 388:	learn: 0.1052075	test: 0.1329070	best: 0.1328873 (385)	total: 39.7s	remaining: 1m 2s
# 389:	learn: 0.1051266	test: 0.1328850	best: 0.1328850 (389)	total: 39.8s	remaining: 1m 2s
# 390:	learn: 0.1050935	test: 0.1328533	best: 0.1328533 (390)	total: 39.9s	remaining: 1m 2s
# 391:	learn: 0.1050356	test: 0.1328776	best: 0.1328533 (390)	total: 40s	remaining: 1m 2s
# 392:	learn: 0.1049224	test: 0.1328831	best: 0.1328533 (390)	total: 40.2s	remaining: 1m 2s
# 393:	learn: 0.1048361	test: 0.1328855	best: 0.1328533 (390)	total: 40.2s	remaining: 1m 1s
# 394:	learn: 0.1047208	test: 0.1329155	best: 0.1328533 (390)	total: 40.4s	remaining: 1m 1s
# 395:	learn: 0.1046312	test: 0.1329054	best: 0.1328533 (390)	total: 40.5s	remaining: 1m 1s
# 396:	learn: 0.1045566	test: 0.1328874	best: 0.1328533 (390)	total: 40.5s	remaining: 1m 1s
# 397:	learn: 0.1044694	test: 0.1328634	best: 0.1328533 (390)	total: 40.6s	remaining: 1m 1s
# 398:	learn: 0.1043924	test: 0.1328713	best: 0.1328533 (390)	total: 40.7s	remaining: 1m 1s
# 399:	learn: 0.1043276	test: 0.1328491	best: 0.1328491 (399)	total: 40.8s	remaining: 1m 1s
# 400:	learn: 0.1042328	test: 0.1328535	best: 0.1328491 (399)	total: 40.8s	remaining: 1m
# 401:	learn: 0.1041412	test: 0.1328048	best: 0.1328048 (401)	total: 40.9s	remaining: 1m
# 402:	learn: 0.1040626	test: 0.1327745	best: 0.1327745 (402)	total: 41s	remaining: 1m
# 403:	learn: 0.1040200	test: 0.1327779	best: 0.1327745 (402)	total: 41.1s	remaining: 1m
# 404:	learn: 0.1039350	test: 0.1327985	best: 0.1327745 (402)	total: 41.1s	remaining: 1m
# 405:	learn: 0.1038711	test: 0.1328050	best: 0.1327745 (402)	total: 41.2s	remaining: 1m
# 406:	learn: 0.1037840	test: 0.1327788	best: 0.1327745 (402)	total: 41.3s	remaining: 1m
# 407:	learn: 0.1036858	test: 0.1327585	best: 0.1327585 (407)	total: 41.3s	remaining: 60s
# 408:	learn: 0.1036264	test: 0.1327494	best: 0.1327494 (408)	total: 41.4s	remaining: 59.9s
# 409:	learn: 0.1035508	test: 0.1327617	best: 0.1327494 (408)	total: 41.5s	remaining: 59.7s
# 410:	learn: 0.1034587	test: 0.1327262	best: 0.1327262 (410)	total: 41.6s	remaining: 59.6s
# 411:	learn: 0.1034047	test: 0.1327227	best: 0.1327227 (411)	total: 41.6s	remaining: 59.4s
# 412:	learn: 0.1033196	test: 0.1327164	best: 0.1327164 (412)	total: 41.7s	remaining: 59.3s
# 413:	learn: 0.1032153	test: 0.1327099	best: 0.1327099 (413)	total: 41.8s	remaining: 59.1s
# 414:	learn: 0.1031500	test: 0.1326474	best: 0.1326474 (414)	total: 41.8s	remaining: 59s
# 415:	learn: 0.1030610	test: 0.1326095	best: 0.1326095 (415)	total: 41.9s	remaining: 58.9s
# 416:	learn: 0.1030168	test: 0.1325979	best: 0.1325979 (416)	total: 42s	remaining: 58.7s
# 417:	learn: 0.1029382	test: 0.1325860	best: 0.1325860 (417)	total: 42.1s	remaining: 58.6s
# 418:	learn: 0.1028626	test: 0.1325512	best: 0.1325512 (418)	total: 42.1s	remaining: 58.4s
# 419:	learn: 0.1028141	test: 0.1325333	best: 0.1325333 (419)	total: 42.2s	remaining: 58.3s
# 420:	learn: 0.1027445	test: 0.1325436	best: 0.1325333 (419)	total: 42.3s	remaining: 58.1s
# 421:	learn: 0.1026540	test: 0.1325354	best: 0.1325333 (419)	total: 42.3s	remaining: 58s
# 422:	learn: 0.1025792	test: 0.1325266	best: 0.1325266 (422)	total: 42.4s	remaining: 57.8s
# 423:	learn: 0.1025209	test: 0.1325461	best: 0.1325266 (422)	total: 42.5s	remaining: 57.7s
# 424:	learn: 0.1024345	test: 0.1325467	best: 0.1325266 (422)	total: 42.5s	remaining: 57.5s
# 425:	learn: 0.1023753	test: 0.1325305	best: 0.1325266 (422)	total: 42.6s	remaining: 57.4s
# 426:	learn: 0.1022907	test: 0.1325364	best: 0.1325266 (422)	total: 42.6s	remaining: 57.2s
# 427:	learn: 0.1022393	test: 0.1325310	best: 0.1325266 (422)	total: 42.7s	remaining: 57.1s
# 428:	learn: 0.1021765	test: 0.1325393	best: 0.1325266 (422)	total: 42.8s	remaining: 56.9s
# 429:	learn: 0.1020964	test: 0.1325453	best: 0.1325266 (422)	total: 42.8s	remaining: 56.8s
# 430:	learn: 0.1020268	test: 0.1324937	best: 0.1324937 (430)	total: 42.9s	remaining: 56.7s
# 431:	learn: 0.1019388	test: 0.1325243	best: 0.1324937 (430)	total: 43s	remaining: 56.5s
# 432:	learn: 0.1018983	test: 0.1325222	best: 0.1324937 (430)	total: 43.1s	remaining: 56.4s
# 433:	learn: 0.1018067	test: 0.1325358	best: 0.1324937 (430)	total: 43.1s	remaining: 56.2s
# 434:	learn: 0.1017364	test: 0.1325241	best: 0.1324937 (430)	total: 43.2s	remaining: 56.1s
# 435:	learn: 0.1016880	test: 0.1325033	best: 0.1324937 (430)	total: 43.3s	remaining: 56s
# 436:	learn: 0.1016588	test: 0.1324801	best: 0.1324801 (436)	total: 43.3s	remaining: 55.8s
# 437:	learn: 0.1015787	test: 0.1325155	best: 0.1324801 (436)	total: 43.4s	remaining: 55.7s
# 438:	learn: 0.1014916	test: 0.1324692	best: 0.1324692 (438)	total: 43.5s	remaining: 55.5s
# 439:	learn: 0.1013743	test: 0.1324529	best: 0.1324529 (439)	total: 43.5s	remaining: 55.4s
# 440:	learn: 0.1013156	test: 0.1324873	best: 0.1324529 (439)	total: 43.6s	remaining: 55.3s
# 441:	learn: 0.1012336	test: 0.1324851	best: 0.1324529 (439)	total: 43.7s	remaining: 55.1s
# 442:	learn: 0.1011817	test: 0.1324683	best: 0.1324529 (439)	total: 43.7s	remaining: 55s
# 443:	learn: 0.1010951	test: 0.1324382	best: 0.1324382 (443)	total: 43.8s	remaining: 54.8s
# 444:	learn: 0.1010249	test: 0.1324739	best: 0.1324382 (443)	total: 43.9s	remaining: 54.7s
# 445:	learn: 0.1009364	test: 0.1324270	best: 0.1324270 (445)	total: 44s	remaining: 54.6s
# 446:	learn: 0.1008944	test: 0.1324260	best: 0.1324260 (446)	total: 44s	remaining: 54.4s
# 447:	learn: 0.1008518	test: 0.1324354	best: 0.1324260 (446)	total: 44.1s	remaining: 54.3s
# 448:	learn: 0.1007973	test: 0.1324079	best: 0.1324079 (448)	total: 44.1s	remaining: 54.2s
# 449:	learn: 0.1006940	test: 0.1323936	best: 0.1323936 (449)	total: 44.2s	remaining: 54s
# 450:	learn: 0.1006253	test: 0.1323809	best: 0.1323809 (450)	total: 44.3s	remaining: 53.9s
# 451:	learn: 0.1005549	test: 0.1323636	best: 0.1323636 (451)	total: 44.3s	remaining: 53.8s
# 452:	learn: 0.1004982	test: 0.1323995	best: 0.1323636 (451)	total: 44.4s	remaining: 53.6s
# 453:	learn: 0.1003917	test: 0.1323810	best: 0.1323636 (451)	total: 44.5s	remaining: 53.5s
# 454:	learn: 0.1003118	test: 0.1323840	best: 0.1323636 (451)	total: 44.6s	remaining: 53.4s
# 455:	learn: 0.1002403	test: 0.1323793	best: 0.1323636 (451)	total: 44.6s	remaining: 53.2s
# 456:	learn: 0.1001925	test: 0.1323738	best: 0.1323636 (451)	total: 44.7s	remaining: 53.1s
# 457:	learn: 0.1001165	test: 0.1323760	best: 0.1323636 (451)	total: 44.8s	remaining: 53s
# 458:	learn: 0.1000216	test: 0.1323420	best: 0.1323420 (458)	total: 44.9s	remaining: 52.9s
# 459:	learn: 0.0999389	test: 0.1323295	best: 0.1323295 (459)	total: 44.9s	remaining: 52.8s
# 460:	learn: 0.0998856	test: 0.1323207	best: 0.1323207 (460)	total: 45s	remaining: 52.6s
# 461:	learn: 0.0998204	test: 0.1323089	best: 0.1323089 (461)	total: 45.1s	remaining: 52.5s
# 462:	learn: 0.0997310	test: 0.1323075	best: 0.1323075 (462)	total: 45.2s	remaining: 52.4s
# 463:	learn: 0.0996731	test: 0.1322843	best: 0.1322843 (463)	total: 45.2s	remaining: 52.2s
# 464:	learn: 0.0995837	test: 0.1322903	best: 0.1322843 (463)	total: 45.3s	remaining: 52.1s
# 465:	learn: 0.0995247	test: 0.1322973	best: 0.1322843 (463)	total: 45.4s	remaining: 52s
# 466:	learn: 0.0994382	test: 0.1322647	best: 0.1322647 (466)	total: 45.5s	remaining: 52s
# 467:	learn: 0.0993716	test: 0.1322749	best: 0.1322647 (466)	total: 45.6s	remaining: 51.8s
# 468:	learn: 0.0993058	test: 0.1323153	best: 0.1322647 (466)	total: 45.7s	remaining: 51.7s
# 469:	learn: 0.0992431	test: 0.1323018	best: 0.1322647 (466)	total: 45.9s	remaining: 51.7s
# 470:	learn: 0.0991495	test: 0.1322905	best: 0.1322647 (466)	total: 46s	remaining: 51.6s
# 471:	learn: 0.0990579	test: 0.1323119	best: 0.1322647 (466)	total: 46.1s	remaining: 51.5s
# 472:	learn: 0.0989620	test: 0.1323186	best: 0.1322647 (466)	total: 46.2s	remaining: 51.5s
# 473:	learn: 0.0988710	test: 0.1322821	best: 0.1322647 (466)	total: 46.3s	remaining: 51.4s
# 474:	learn: 0.0988100	test: 0.1322783	best: 0.1322647 (466)	total: 46.5s	remaining: 51.4s
# 475:	learn: 0.0987496	test: 0.1322743	best: 0.1322647 (466)	total: 46.6s	remaining: 51.3s
# 476:	learn: 0.0986916	test: 0.1322635	best: 0.1322635 (476)	total: 46.7s	remaining: 51.2s
# 477:	learn: 0.0986187	test: 0.1322689	best: 0.1322635 (476)	total: 46.8s	remaining: 51.1s
# 478:	learn: 0.0985383	test: 0.1322410	best: 0.1322410 (478)	total: 46.9s	remaining: 51s
# 479:	learn: 0.0985153	test: 0.1322262	best: 0.1322262 (479)	total: 47s	remaining: 50.9s
# 480:	learn: 0.0984311	test: 0.1322300	best: 0.1322262 (479)	total: 47.1s	remaining: 50.8s
# 481:	learn: 0.0983399	test: 0.1322223	best: 0.1322223 (481)	total: 47.2s	remaining: 50.8s
# 482:	learn: 0.0982984	test: 0.1322105	best: 0.1322105 (482)	total: 47.3s	remaining: 50.6s
# 483:	learn: 0.0982519	test: 0.1322102	best: 0.1322102 (483)	total: 47.4s	remaining: 50.5s
# 484:	learn: 0.0981973	test: 0.1321872	best: 0.1321872 (484)	total: 47.5s	remaining: 50.5s
# 485:	learn: 0.0980981	test: 0.1322116	best: 0.1321872 (484)	total: 47.6s	remaining: 50.3s
# 486:	learn: 0.0980376	test: 0.1322290	best: 0.1321872 (484)	total: 47.7s	remaining: 50.2s
# 487:	learn: 0.0979291	test: 0.1322416	best: 0.1321872 (484)	total: 47.8s	remaining: 50.2s
# 488:	learn: 0.0978465	test: 0.1322401	best: 0.1321872 (484)	total: 47.9s	remaining: 50.1s
# 489:	learn: 0.0977540	test: 0.1321961	best: 0.1321872 (484)	total: 48.1s	remaining: 50s
# 490:	learn: 0.0977041	test: 0.1321875	best: 0.1321872 (484)	total: 48.2s	remaining: 49.9s
# 491:	learn: 0.0976340	test: 0.1322236	best: 0.1321872 (484)	total: 48.3s	remaining: 49.8s
# 492:	learn: 0.0975688	test: 0.1321796	best: 0.1321796 (492)	total: 48.4s	remaining: 49.8s
# 493:	learn: 0.0975082	test: 0.1321768	best: 0.1321768 (493)	total: 48.5s	remaining: 49.7s
# 494:	learn: 0.0974343	test: 0.1322013	best: 0.1321768 (493)	total: 48.6s	remaining: 49.6s
# 495:	learn: 0.0973590	test: 0.1322017	best: 0.1321768 (493)	total: 48.7s	remaining: 49.5s
# 496:	learn: 0.0972581	test: 0.1322082	best: 0.1321768 (493)	total: 48.9s	remaining: 49.5s
# 497:	learn: 0.0971868	test: 0.1322088	best: 0.1321768 (493)	total: 49s	remaining: 49.4s
# 498:	learn: 0.0971575	test: 0.1321869	best: 0.1321768 (493)	total: 49.1s	remaining: 49.3s
# 499:	learn: 0.0971018	test: 0.1321963	best: 0.1321768 (493)	total: 49.2s	remaining: 49.2s
# 500:	learn: 0.0970647	test: 0.1321598	best: 0.1321598 (500)	total: 49.3s	remaining: 49.1s
# 501:	learn: 0.0970244	test: 0.1321701	best: 0.1321598 (500)	total: 49.4s	remaining: 49s
# 502:	learn: 0.0969638	test: 0.1321342	best: 0.1321342 (502)	total: 49.5s	remaining: 48.9s
# 503:	learn: 0.0968747	test: 0.1321278	best: 0.1321278 (503)	total: 49.6s	remaining: 48.8s
# 504:	learn: 0.0968078	test: 0.1320732	best: 0.1320732 (504)	total: 49.7s	remaining: 48.7s
# 505:	learn: 0.0967380	test: 0.1320713	best: 0.1320713 (505)	total: 49.7s	remaining: 48.5s
# 506:	learn: 0.0966699	test: 0.1320740	best: 0.1320713 (505)	total: 49.8s	remaining: 48.4s
# 507:	learn: 0.0965897	test: 0.1320617	best: 0.1320617 (507)	total: 49.9s	remaining: 48.3s
# 508:	learn: 0.0965235	test: 0.1320699	best: 0.1320617 (507)	total: 50s	remaining: 48.2s
# 509:	learn: 0.0964718	test: 0.1320674	best: 0.1320617 (507)	total: 50s	remaining: 48.1s
# 510:	learn: 0.0964244	test: 0.1320769	best: 0.1320617 (507)	total: 50.1s	remaining: 47.9s
# 511:	learn: 0.0963575	test: 0.1320916	best: 0.1320617 (507)	total: 50.2s	remaining: 47.8s
# 512:	learn: 0.0963235	test: 0.1321057	best: 0.1320617 (507)	total: 50.2s	remaining: 47.7s
# 513:	learn: 0.0962720	test: 0.1321197	best: 0.1320617 (507)	total: 50.3s	remaining: 47.6s
# 514:	learn: 0.0961763	test: 0.1321052	best: 0.1320617 (507)	total: 50.4s	remaining: 47.5s
# 515:	learn: 0.0960992	test: 0.1320647	best: 0.1320617 (507)	total: 50.5s	remaining: 47.4s
# 516:	learn: 0.0960098	test: 0.1320000	best: 0.1320000 (516)	total: 50.6s	remaining: 47.3s
# 517:	learn: 0.0959315	test: 0.1320243	best: 0.1320000 (516)	total: 50.7s	remaining: 47.2s
# 518:	learn: 0.0958626	test: 0.1320120	best: 0.1320000 (516)	total: 50.7s	remaining: 47s
# 519:	learn: 0.0958211	test: 0.1319974	best: 0.1319974 (519)	total: 50.8s	remaining: 46.9s
# 520:	learn: 0.0957394	test: 0.1320221	best: 0.1319974 (519)	total: 50.9s	remaining: 46.8s
# 521:	learn: 0.0956937	test: 0.1320185	best: 0.1319974 (519)	total: 51s	remaining: 46.7s
# 522:	learn: 0.0955928	test: 0.1319796	best: 0.1319796 (522)	total: 51.1s	remaining: 46.6s
# 523:	learn: 0.0955281	test: 0.1319891	best: 0.1319796 (522)	total: 51.1s	remaining: 46.4s
# 524:	learn: 0.0954530	test: 0.1320192	best: 0.1319796 (522)	total: 51.2s	remaining: 46.3s
# 525:	learn: 0.0953840	test: 0.1320182	best: 0.1319796 (522)	total: 51.3s	remaining: 46.2s
# 526:	learn: 0.0953269	test: 0.1320413	best: 0.1319796 (522)	total: 51.4s	remaining: 46.1s
# 527:	learn: 0.0952837	test: 0.1320213	best: 0.1319796 (522)	total: 51.5s	remaining: 46s
# 528:	learn: 0.0952305	test: 0.1320147	best: 0.1319796 (522)	total: 51.5s	remaining: 45.9s
# 529:	learn: 0.0951744	test: 0.1320281	best: 0.1319796 (522)	total: 51.6s	remaining: 45.8s
# 530:	learn: 0.0951110	test: 0.1319908	best: 0.1319796 (522)	total: 51.7s	remaining: 45.6s
# 531:	learn: 0.0950499	test: 0.1319807	best: 0.1319796 (522)	total: 51.8s	remaining: 45.6s
# ...
# 825:	learn: 0.0827705	test: 0.1295254	best: 0.1294037 (723)	total: 1m 28s	remaining: 18.7s
# 826:	learn: 0.0827442	test: 0.1295305	best: 0.1294037 (723)	total: 1m 28s	remaining: 18.5s
# 827:	learn: 0.0827032	test: 0.1295119	best: 0.1294037 (723)	total: 1m 28s	remaining: 18.4s
# 828:	learn: 0.0826666	test: 0.1295025	best: 0.1294037 (723)	total: 1m 28s	remaining: 18.3s
# 829:	learn: 0.0826327	test: 0.1295173	best: 0.1294037 (723)	total: 1m 28s	remaining: 18.2s
# 830:	learn: 0.0825793	test: 0.1295182	best: 0.1294037 (723)	total: 1m 28s	remaining: 18.1s
# 831:	learn: 0.0825503	test: 0.1295054	best: 0.1294037 (723)	total: 1m 28s	remaining: 18s
# 832:	learn: 0.0824947	test: 0.1294959	best: 0.1294037 (723)	total: 1m 29s	remaining: 17.8s
# 833:	learn: 0.0824674	test: 0.1294990	best: 0.1294037 (723)	total: 1m 29s	remaining: 17.7s
# 834:	learn: 0.0824020	test: 0.1295013	best: 0.1294037 (723)	total: 1m 29s	remaining: 17.6s
# 835:	learn: 0.0823652	test: 0.1294692	best: 0.1294037 (723)	total: 1m 29s	remaining: 17.5s
# 836:	learn: 0.0823168	test: 0.1294885	best: 0.1294037 (723)	total: 1m 29s	remaining: 17.4s
# 837:	learn: 0.0822980	test: 0.1294876	best: 0.1294037 (723)	total: 1m 29s	remaining: 17.3s
# 838:	learn: 0.0822346	test: 0.1294905	best: 0.1294037 (723)	total: 1m 29s	remaining: 17.2s
# 839:	learn: 0.0822061	test: 0.1294861	best: 0.1294037 (723)	total: 1m 29s	remaining: 17s
# 840:	learn: 0.0821690	test: 0.1295069	best: 0.1294037 (723)	total: 1m 29s	remaining: 16.9s
# 841:	learn: 0.0821157	test: 0.1295438	best: 0.1294037 (723)	total: 1m 29s	remaining: 16.8s
# 842:	learn: 0.0820760	test: 0.1295557	best: 0.1294037 (723)	total: 1m 29s	remaining: 16.7s
# 843:	learn: 0.0820171	test: 0.1295816	best: 0.1294037 (723)	total: 1m 29s	remaining: 16.6s
# 844:	learn: 0.0819744	test: 0.1296125	best: 0.1294037 (723)	total: 1m 29s	remaining: 16.5s
# 845:	learn: 0.0819421	test: 0.1295940	best: 0.1294037 (723)	total: 1m 29s	remaining: 16.4s
# 846:	learn: 0.0819163	test: 0.1295943	best: 0.1294037 (723)	total: 1m 29s	remaining: 16.2s
# 847:	learn: 0.0818612	test: 0.1295965	best: 0.1294037 (723)	total: 1m 30s	remaining: 16.1s
# 848:	learn: 0.0817958	test: 0.1295756	best: 0.1294037 (723)	total: 1m 30s	remaining: 16s
# 849:	learn: 0.0817728	test: 0.1295933	best: 0.1294037 (723)	total: 1m 30s	remaining: 15.9s
# 850:	learn: 0.0817044	test: 0.1296052	best: 0.1294037 (723)	total: 1m 30s	remaining: 15.8s
# 851:	learn: 0.0816684	test: 0.1295588	best: 0.1294037 (723)	total: 1m 30s	remaining: 15.7s
# 852:	learn: 0.0816229	test: 0.1295647	best: 0.1294037 (723)	total: 1m 30s	remaining: 15.6s
# 853:	learn: 0.0815952	test: 0.1295587	best: 0.1294037 (723)	total: 1m 30s	remaining: 15.5s
# 854:	learn: 0.0815379	test: 0.1295342	best: 0.1294037 (723)	total: 1m 30s	remaining: 15.3s
# 855:	learn: 0.0814880	test: 0.1295324	best: 0.1294037 (723)	total: 1m 30s	remaining: 15.2s
# 856:	learn: 0.0814194	test: 0.1295311	best: 0.1294037 (723)	total: 1m 30s	remaining: 15.1s
# 857:	learn: 0.0813671	test: 0.1295026	best: 0.1294037 (723)	total: 1m 30s	remaining: 15s
# 858:	learn: 0.0813234	test: 0.1295275	best: 0.1294037 (723)	total: 1m 30s	remaining: 14.9s
# 859:	learn: 0.0812946	test: 0.1295354	best: 0.1294037 (723)	total: 1m 30s	remaining: 14.8s
# 860:	learn: 0.0812371	test: 0.1294965	best: 0.1294037 (723)	total: 1m 30s	remaining: 14.7s
# 861:	learn: 0.0812020	test: 0.1294945	best: 0.1294037 (723)	total: 1m 31s	remaining: 14.6s
# 862:	learn: 0.0811739	test: 0.1294819	best: 0.1294037 (723)	total: 1m 31s	remaining: 14.5s
# 863:	learn: 0.0811495	test: 0.1294608	best: 0.1294037 (723)	total: 1m 31s	remaining: 14.4s
# 864:	learn: 0.0811089	test: 0.1294623	best: 0.1294037 (723)	total: 1m 31s	remaining: 14.3s
# 865:	learn: 0.0810800	test: 0.1294470	best: 0.1294037 (723)	total: 1m 31s	remaining: 14.2s
# 866:	learn: 0.0810150	test: 0.1294216	best: 0.1294037 (723)	total: 1m 31s	remaining: 14.1s
# 867:	learn: 0.0809380	test: 0.1293891	best: 0.1293891 (867)	total: 1m 31s	remaining: 14s
# 868:	learn: 0.0808932	test: 0.1294062	best: 0.1293891 (867)	total: 1m 31s	remaining: 13.9s
# 869:	learn: 0.0808494	test: 0.1294031	best: 0.1293891 (867)	total: 1m 32s	remaining: 13.8s
# 870:	learn: 0.0807823	test: 0.1294335	best: 0.1293891 (867)	total: 1m 32s	remaining: 13.7s
# 871:	learn: 0.0807571	test: 0.1294223	best: 0.1293891 (867)	total: 1m 32s	remaining: 13.5s
# 872:	learn: 0.0807025	test: 0.1294189	best: 0.1293891 (867)	total: 1m 32s	remaining: 13.4s
# 873:	learn: 0.0806537	test: 0.1294301	best: 0.1293891 (867)	total: 1m 32s	remaining: 13.3s
# 874:	learn: 0.0806010	test: 0.1294211	best: 0.1293891 (867)	total: 1m 32s	remaining: 13.2s
# 875:	learn: 0.0805274	test: 0.1294216	best: 0.1293891 (867)	total: 1m 32s	remaining: 13.1s
# 876:	learn: 0.0804778	test: 0.1294214	best: 0.1293891 (867)	total: 1m 32s	remaining: 13s
# 877:	learn: 0.0804128	test: 0.1294400	best: 0.1293891 (867)	total: 1m 32s	remaining: 12.9s
# 878:	learn: 0.0803617	test: 0.1294397	best: 0.1293891 (867)	total: 1m 33s	remaining: 12.8s
# 879:	learn: 0.0803435	test: 0.1294238	best: 0.1293891 (867)	total: 1m 33s	remaining: 12.7s
# 880:	learn: 0.0802699	test: 0.1294245	best: 0.1293891 (867)	total: 1m 33s	remaining: 12.6s
# 881:	learn: 0.0802213	test: 0.1294176	best: 0.1293891 (867)	total: 1m 33s	remaining: 12.5s
# 882:	learn: 0.0801762	test: 0.1294022	best: 0.1293891 (867)	total: 1m 33s	remaining: 12.4s
# 883:	learn: 0.0801548	test: 0.1293973	best: 0.1293891 (867)	total: 1m 33s	remaining: 12.3s
# 884:	learn: 0.0801200	test: 0.1294073	best: 0.1293891 (867)	total: 1m 33s	remaining: 12.2s
# 885:	learn: 0.0800893	test: 0.1293993	best: 0.1293891 (867)	total: 1m 33s	remaining: 12.1s
# 886:	learn: 0.0800390	test: 0.1294219	best: 0.1293891 (867)	total: 1m 33s	remaining: 12s
# 887:	learn: 0.0800206	test: 0.1294244	best: 0.1293891 (867)	total: 1m 34s	remaining: 11.9s
# 888:	learn: 0.0799975	test: 0.1294264	best: 0.1293891 (867)	total: 1m 34s	remaining: 11.8s
# 889:	learn: 0.0799561	test: 0.1294572	best: 0.1293891 (867)	total: 1m 34s	remaining: 11.6s
# 890:	learn: 0.0798992	test: 0.1294481	best: 0.1293891 (867)	total: 1m 34s	remaining: 11.5s
# 891:	learn: 0.0798519	test: 0.1294433	best: 0.1293891 (867)	total: 1m 34s	remaining: 11.4s
# 892:	learn: 0.0798180	test: 0.1294495	best: 0.1293891 (867)	total: 1m 34s	remaining: 11.3s
# 893:	learn: 0.0797850	test: 0.1294394	best: 0.1293891 (867)	total: 1m 34s	remaining: 11.2s
# 894:	learn: 0.0797372	test: 0.1294240	best: 0.1293891 (867)	total: 1m 34s	remaining: 11.1s
# 895:	learn: 0.0796911	test: 0.1294122	best: 0.1293891 (867)	total: 1m 34s	remaining: 11s
# 896:	learn: 0.0796675	test: 0.1294015	best: 0.1293891 (867)	total: 1m 34s	remaining: 10.9s
# 897:	learn: 0.0796362	test: 0.1294173	best: 0.1293891 (867)	total: 1m 34s	remaining: 10.8s
# 898:	learn: 0.0795983	test: 0.1294395	best: 0.1293891 (867)	total: 1m 35s	remaining: 10.7s
# 899:	learn: 0.0795552	test: 0.1294415	best: 0.1293891 (867)	total: 1m 35s	remaining: 10.6s
# 900:	learn: 0.0794852	test: 0.1294280	best: 0.1293891 (867)	total: 1m 35s	remaining: 10.5s
# 901:	learn: 0.0794408	test: 0.1294272	best: 0.1293891 (867)	total: 1m 35s	remaining: 10.3s
# 902:	learn: 0.0793829	test: 0.1294045	best: 0.1293891 (867)	total: 1m 35s	remaining: 10.2s
# 903:	learn: 0.0793681	test: 0.1294046	best: 0.1293891 (867)	total: 1m 35s	remaining: 10.1s
# 904:	learn: 0.0793217	test: 0.1294067	best: 0.1293891 (867)	total: 1m 35s	remaining: 10s
# 905:	learn: 0.0792853	test: 0.1294269	best: 0.1293891 (867)	total: 1m 35s	remaining: 9.91s
# 906:	learn: 0.0792550	test: 0.1294607	best: 0.1293891 (867)	total: 1m 35s	remaining: 9.8s
# 907:	learn: 0.0791823	test: 0.1294310	best: 0.1293891 (867)	total: 1m 35s	remaining: 9.69s
# 908:	learn: 0.0791489	test: 0.1294089	best: 0.1293891 (867)	total: 1m 35s	remaining: 9.58s
# 909:	learn: 0.0790945	test: 0.1294065	best: 0.1293891 (867)	total: 1m 35s	remaining: 9.47s
# 910:	learn: 0.0790611	test: 0.1294043	best: 0.1293891 (867)	total: 1m 35s	remaining: 9.36s
# 911:	learn: 0.0790335	test: 0.1294077	best: 0.1293891 (867)	total: 1m 35s	remaining: 9.25s
# 912:	learn: 0.0790054	test: 0.1294128	best: 0.1293891 (867)	total: 1m 35s	remaining: 9.15s
# 913:	learn: 0.0789601	test: 0.1294017	best: 0.1293891 (867)	total: 1m 36s	remaining: 9.04s
# 914:	learn: 0.0789347	test: 0.1294152	best: 0.1293891 (867)	total: 1m 36s	remaining: 8.93s
# 915:	learn: 0.0788849	test: 0.1294219	best: 0.1293891 (867)	total: 1m 36s	remaining: 8.82s
# 916:	learn: 0.0788268	test: 0.1294033	best: 0.1293891 (867)	total: 1m 36s	remaining: 8.71s
# 917:	learn: 0.0787861	test: 0.1294237	best: 0.1293891 (867)	total: 1m 36s	remaining: 8.6s
# 918:	learn: 0.0787653	test: 0.1294297	best: 0.1293891 (867)	total: 1m 36s	remaining: 8.49s
# 919:	learn: 0.0786788	test: 0.1294592	best: 0.1293891 (867)	total: 1m 36s	remaining: 8.39s
# 920:	learn: 0.0786142	test: 0.1294940	best: 0.1293891 (867)	total: 1m 36s	remaining: 8.28s
# 921:	learn: 0.0785801	test: 0.1295033	best: 0.1293891 (867)	total: 1m 36s	remaining: 8.17s
# 922:	learn: 0.0785426	test: 0.1295042	best: 0.1293891 (867)	total: 1m 36s	remaining: 8.06s
# 923:	learn: 0.0784984	test: 0.1294831	best: 0.1293891 (867)	total: 1m 36s	remaining: 7.95s
# 924:	learn: 0.0784482	test: 0.1294937	best: 0.1293891 (867)	total: 1m 36s	remaining: 7.85s
# 925:	learn: 0.0784106	test: 0.1294766	best: 0.1293891 (867)	total: 1m 36s	remaining: 7.74s
# 926:	learn: 0.0783677	test: 0.1294728	best: 0.1293891 (867)	total: 1m 36s	remaining: 7.63s
# 927:	learn: 0.0783002	test: 0.1294851	best: 0.1293891 (867)	total: 1m 36s	remaining: 7.52s
# 928:	learn: 0.0782436	test: 0.1294701	best: 0.1293891 (867)	total: 1m 37s	remaining: 7.42s
# 929:	learn: 0.0782135	test: 0.1294608	best: 0.1293891 (867)	total: 1m 37s	remaining: 7.31s
# 930:	learn: 0.0781709	test: 0.1294558	best: 0.1293891 (867)	total: 1m 37s	remaining: 7.2s
# 931:	learn: 0.0781137	test: 0.1294618	best: 0.1293891 (867)	total: 1m 37s	remaining: 7.09s
# 932:	learn: 0.0780674	test: 0.1294681	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.99s
# 933:	learn: 0.0780354	test: 0.1294774	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.88s
# 934:	learn: 0.0779908	test: 0.1294592	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.77s
# 935:	learn: 0.0779562	test: 0.1294495	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.67s
# 936:	learn: 0.0779136	test: 0.1294755	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.56s
# 937:	learn: 0.0778749	test: 0.1294707	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.45s
# 938:	learn: 0.0778265	test: 0.1294762	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.35s
# 939:	learn: 0.0777621	test: 0.1294766	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.24s
# 940:	learn: 0.0777027	test: 0.1294874	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.13s
# 941:	learn: 0.0776661	test: 0.1294945	best: 0.1293891 (867)	total: 1m 37s	remaining: 6.03s
# 942:	learn: 0.0776074	test: 0.1294651	best: 0.1293891 (867)	total: 1m 37s	remaining: 5.92s
# 943:	learn: 0.0775416	test: 0.1294887	best: 0.1293891 (867)	total: 1m 38s	remaining: 5.82s
# 944:	learn: 0.0774894	test: 0.1294873	best: 0.1293891 (867)	total: 1m 38s	remaining: 5.71s
# 945:	learn: 0.0774688	test: 0.1295163	best: 0.1293891 (867)	total: 1m 38s	remaining: 5.61s
# 946:	learn: 0.0774376	test: 0.1295162	best: 0.1293891 (867)	total: 1m 38s	remaining: 5.5s
# 947:	learn: 0.0773846	test: 0.1294862	best: 0.1293891 (867)	total: 1m 38s	remaining: 5.41s
# 948:	learn: 0.0773293	test: 0.1295011	best: 0.1293891 (867)	total: 1m 38s	remaining: 5.3s
# 949:	learn: 0.0772934	test: 0.1295159	best: 0.1293891 (867)	total: 1m 38s	remaining: 5.2s
# 950:	learn: 0.0772356	test: 0.1295391	best: 0.1293891 (867)	total: 1m 38s	remaining: 5.09s
# 951:	learn: 0.0772255	test: 0.1295397	best: 0.1293891 (867)	total: 1m 38s	remaining: 4.98s
# 952:	learn: 0.0771686	test: 0.1295467	best: 0.1293891 (867)	total: 1m 38s	remaining: 4.88s
# 953:	learn: 0.0771225	test: 0.1295522	best: 0.1293891 (867)	total: 1m 39s	remaining: 4.78s
# 954:	learn: 0.0770905	test: 0.1295605	best: 0.1293891 (867)	total: 1m 39s	remaining: 4.67s
# 955:	learn: 0.0770323	test: 0.1295754	best: 0.1293891 (867)	total: 1m 39s	remaining: 4.57s
# 956:	learn: 0.0769832	test: 0.1295654	best: 0.1293891 (867)	total: 1m 39s	remaining: 4.46s
# 957:	learn: 0.0769118	test: 0.1295617	best: 0.1293891 (867)	total: 1m 39s	remaining: 4.36s
# 958:	learn: 0.0768323	test: 0.1295654	best: 0.1293891 (867)	total: 1m 39s	remaining: 4.25s
# 959:	learn: 0.0768071	test: 0.1295442	best: 0.1293891 (867)	total: 1m 39s	remaining: 4.15s
# 960:	learn: 0.0767798	test: 0.1295485	best: 0.1293891 (867)	total: 1m 39s	remaining: 4.04s
# 961:	learn: 0.0767403	test: 0.1295523	best: 0.1293891 (867)	total: 1m 39s	remaining: 3.94s
# 962:	learn: 0.0766966	test: 0.1295490	best: 0.1293891 (867)	total: 1m 39s	remaining: 3.84s
# 963:	learn: 0.0766400	test: 0.1295881	best: 0.1293891 (867)	total: 1m 40s	remaining: 3.73s
# 964:	learn: 0.0766040	test: 0.1296123	best: 0.1293891 (867)	total: 1m 40s	remaining: 3.64s
# 965:	learn: 0.0765757	test: 0.1296036	best: 0.1293891 (867)	total: 1m 40s	remaining: 3.53s
# 966:	learn: 0.0765492	test: 0.1296079	best: 0.1293891 (867)	total: 1m 40s	remaining: 3.43s
# 967:	learn: 0.0764920	test: 0.1296090	best: 0.1293891 (867)	total: 1m 40s	remaining: 3.33s
# 968:	learn: 0.0764489	test: 0.1296446	best: 0.1293891 (867)	total: 1m 40s	remaining: 3.23s
# 969:	learn: 0.0763950	test: 0.1296466	best: 0.1293891 (867)	total: 1m 41s	remaining: 3.12s
# 970:	learn: 0.0763534	test: 0.1296403	best: 0.1293891 (867)	total: 1m 41s	remaining: 3.02s
# 971:	learn: 0.0763094	test: 0.1296790	best: 0.1293891 (867)	total: 1m 41s	remaining: 2.92s
# 972:	learn: 0.0762708	test: 0.1296754	best: 0.1293891 (867)	total: 1m 41s	remaining: 2.81s
# 973:	learn: 0.0762534	test: 0.1296618	best: 0.1293891 (867)	total: 1m 41s	remaining: 2.71s
# 974:	learn: 0.0761923	test: 0.1296735	best: 0.1293891 (867)	total: 1m 41s	remaining: 2.61s
# 975:	learn: 0.0761546	test: 0.1296539	best: 0.1293891 (867)	total: 1m 41s	remaining: 2.5s
# 976:	learn: 0.0760994	test: 0.1296754	best: 0.1293891 (867)	total: 1m 41s	remaining: 2.4s
# 977:	learn: 0.0760530	test: 0.1296903	best: 0.1293891 (867)	total: 1m 42s	remaining: 2.3s
# 978:	learn: 0.0760345	test: 0.1296966	best: 0.1293891 (867)	total: 1m 42s	remaining: 2.2s
# 979:	learn: 0.0759810	test: 0.1297090	best: 0.1293891 (867)	total: 1m 42s	remaining: 2.09s
# 980:	learn: 0.0759475	test: 0.1297193	best: 0.1293891 (867)	total: 1m 42s	remaining: 1.99s
# 981:	learn: 0.0758920	test: 0.1297162	best: 0.1293891 (867)	total: 1m 42s	remaining: 1.89s
# 982:	learn: 0.0758812	test: 0.1297166	best: 0.1293891 (867)	total: 1m 42s	remaining: 1.78s
# 983:	learn: 0.0758477	test: 0.1297112	best: 0.1293891 (867)	total: 1m 43s	remaining: 1.68s
# 984:	learn: 0.0758060	test: 0.1297247	best: 0.1293891 (867)	total: 1m 43s	remaining: 1.57s
# 985:	learn: 0.0757693	test: 0.1297239	best: 0.1293891 (867)	total: 1m 43s	remaining: 1.47s
# 986:	learn: 0.0757321	test: 0.1297419	best: 0.1293891 (867)	total: 1m 43s	remaining: 1.36s
# 987:	learn: 0.0756762	test: 0.1297322	best: 0.1293891 (867)	total: 1m 43s	remaining: 1.26s
# 988:	learn: 0.0756597	test: 0.1297358	best: 0.1293891 (867)	total: 1m 43s	remaining: 1.15s
# 989:	learn: 0.0756420	test: 0.1297049	best: 0.1293891 (867)	total: 1m 43s	remaining: 1.05s
# 990:	learn: 0.0755961	test: 0.1297003	best: 0.1293891 (867)	total: 1m 44s	remaining: 945ms
# 991:	learn: 0.0755742	test: 0.1297013	best: 0.1293891 (867)	total: 1m 44s	remaining: 840ms
# 992:	learn: 0.0755396	test: 0.1296748	best: 0.1293891 (867)	total: 1m 44s	remaining: 735ms
# 993:	learn: 0.0755031	test: 0.1296445	best: 0.1293891 (867)	total: 1m 44s	remaining: 629ms
# 994:	learn: 0.0754739	test: 0.1296511	best: 0.1293891 (867)	total: 1m 44s	remaining: 524ms
# 995:	learn: 0.0754526	test: 0.1296445	best: 0.1293891 (867)	total: 1m 44s	remaining: 420ms
# 996:	learn: 0.0754074	test: 0.1296563	best: 0.1293891 (867)	total: 1m 44s	remaining: 315ms
# 997:	learn: 0.0753496	test: 0.1296631	best: 0.1293891 (867)	total: 1m 44s	remaining: 210ms
# 998:	learn: 0.0753106	test: 0.1296298	best: 0.1293891 (867)	total: 1m 44s	remaining: 105ms
# 999:	learn: 0.0752648	test: 0.1296017	best: 0.1293891 (867)	total: 1m 45s	remaining: 0us
#
# bestTest = 0.1293891004
# bestIteration = 867
#
# Shrink model to first 868 iterations.

# %%
# Score the results
feature_results = custom_score(X_test, y_test, feature_model)
# Out:
# Model Results
# Accuracy: 0.95
# Precision: 0.76
# Recall: 0.63
# F1: 0.69
# ROC AUC: 0.96
# {'Accuracy': 0.9483984841405804,
#  'Precision': 0.7629009762900977,
#  'Recall': 0.6258581235697941,
#  'F1': 0.6876178504085482,
#  'ROCAUC': 0.9631290864776906}

# %%
custom_change(FSM_results, feature_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/y8/vq429chs6djb0hl0y0zp5fg00000gn/T/ipykernel_66263/2870096032.py in <module>
# ----> 1 custom_change(FSM_results, feature_results)
#
# NameError: name 'feature_results' is not defined

# %%
# Removing eliminated features from training and test sets.
X_train.drop(columns=summary['eliminated_features_names'], inplace=True)
X_test.drop(columns=summary['eliminated_features_names'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/y8/vq429chs6djb0hl0y0zp5fg00000gn/T/ipykernel_66263/1002199843.py in <module>
#       1 X_train.drop(columns=summary['eliminated_features_names'], inplace=True)
# ----> 2 X_test.drop(columns=summary['eliminated_features_names'], inplace=True)
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/envs/Capstone/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['K2Q34C' 'K2Q42C' 'K4Q37' 'SCREENTIME' 'BIRTHWT_OZ_S' 'STOMACH'\n 'A2_GRADE' 'A2_AGE' 'ACE7' 'A1_DEPLSTAT' 'K4Q28X01' 'A2_DEPLSTAT'\n 'K10Q11' 'ARRANGEHC' 'ALTHEALTH' 'RAISECONC' 'K7Q30' 'HOURSLEEP' 'K7Q37'\n 'K5Q20_R' 'SC_K2Q17' 'WGTCONC' 'HEADACHE_DESC' 'STRENGTHS' 'ACE5'\n 'K2Q36B' 'K8Q34' 'USUALSICK' 'FPL_I1' 'SESPLANMO' 'K4Q32X02' 'A2_MARITAL'\n 'OVERWEIGHT' 'TOTAGE_12_17' 'DENTALSERV3' 'K2Q42B' 'FPL_I2' 'LIVEUSA_YR'\n 'K3Q25' 'K11Q43R' 'K12Q01_A' 'MAKEFRIEND' 'ACE1' 'BULLY' 'PHYSACTIV'\n 'RECEIVECOPY' 'K5Q22' 'PLANNEEDS_R' 'FPL_I6' 'K6Q71_R' 'K11Q60' 'K4Q04_R'\n 'K4Q30_R' 'HOPEFUL' 'K12Q01_B' 'INSTYPE' 'K12Q12' 'BLINDNESS' 'K12Q03'\n 'K2Q05' 'K2Q38C' 'FPL_I4' 'CUTHOURS' 'K7Q70_R' 'FPL_I5' 'APPOINTMENT'\n 'K2Q42A' 'DISCUSSOPT' 'DOCPRIVATE' 'A2_ACTIVE' 'K8Q11' 'ACE6'\n 'HIGRADE_TVIS' 'TOTFEMALE' 'WALKSTAIRS' 'TRANSPORTCC' 'AVOIDCHG' 'INSGAP'\n 'K10Q30' 'SC_K2Q18' 'K4Q01' 'HIGRADE' 'K12Q01_C' 'K5Q41' 'K4Q31_R'\n 'K10Q12' 'C4Q04' 'USUALGO' 'K8Q35' 'CAVITIES' 'K4Q32X01' 'K11Q61'\n 'HEART_DESC' 'GENETIC_DESC' 'K2Q35B' 'HOSPITALSTAY' 'A1_RELATION'\n 'RHYMEWORD' 'K5Q10' 'A2_BORN' 'K12Q01_G' 'KEEPINSADULT' 'K2Q40B'\n 'K12Q01_F' 'EMOSUPSPO' 'K9Q40' 'K11Q03R' 'K2Q38A' 'BIRTHWT' 'MEDHISTORY'\n 'USEPENCIL' 'BIRTHWT_VL' 'FPL_IF' 'FPL_I3' 'K7Q33' 'SC_K2Q13' 'K7Q04R_R'\n 'DOWNSYN' 'K7Q31' 'A2_LIVEUSA' 'DENTALSERV5' 'K3Q21B' 'BIRTHWT_L'\n 'K2Q40A' 'ACE3' 'K5Q43' 'K2Q60C' 'A2_PHYSHEALTH' 'GOFORHELP' 'TENURE'\n 'CERPALS_DESC' 'DENTALSERV7' 'PLAYWELL' 'HEART_CURR' 'K2Q36A' 'NOTELIG'\n 'CLEAREXP' 'K8Q32' 'SC_K2Q21' 'HOSPITALER' 'TOTMALE' 'K5Q44' 'K4Q32X03'\n 'EMOSUPMHP' 'EMOSUPPEER' 'K3Q04_R' 'FAMCOUNT' 'A1_MARITAL' 'HOUSE_GEN'\n 'WKTOSOLVE' 'DENTALSERV2' 'BEDTIME' 'HOURSLEEP05' 'DECISIONS' 'K2Q61A'\n 'MPC_YN' 'DENTISTVISIT'] not found in axis"

# %% [markdown]
# # Hyper-parameter tuning with Optima
# From here, I will be tuning our Catboost model using the [Optuna](https://optuna.readthedocs.io/en/stable/index.html) library. The library will allow me to easily test many hyper-parameters to find the optimal configuration.

# %%
# Importing packages needed for this section
from sklearn.metrics import roc_auc_score, f1_score, recall_score, accuracy_score
import optuna

# %%
# Optuna requires us to define the "objective function". Which will be called upon each iteration during our "trials"
def objective(trial):
    # Dict of Parameters to check
    param = {
        # Metric used for model optimization
        # 'loss_function': trial.suggest_categorical('loss_function', ['Logloss', 'CrossEntropy']),

        # The maximum number of trees that can be built.
        'iterations': trial.suggest_categorical('iterations', [100, 200, 300, 500, 1000]),

        # learning rate for gradient descent calculations.
        'learning_rate': trial.suggest_float("learning_rate", 0.001, 0.3),

        # Coefficient at the L2 regularization term of the cost function.
        'l2_leaf_reg': trial.suggest_loguniform("l2_leaf_reg", 1e-8, 100),

        # Affects the speed and regularization of tree
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),

        # The amount of randomness to use for scoring splits.
        'random_strength': trial.suggest_int("random_strength", 1, 10),

        # The number of splits for numerical features.
        'max_bin': trial.suggest_categorical('max_bin', [4, 5, 6, 8, 10, 20, 30]),

        # Allowed depth of tree.
        "depth": trial.suggest_int("max_depth", 2, 16),

        # Defines how to perform greedy tree construction.
        'grow_policy': trial.suggest_categorical('grow_policy', ['SymmetricTree', 'Depthwise', 'Lossguide']),

        # The minimum number of training samples in a leaf.
        'min_data_in_leaf': trial.suggest_int("min_data_in_leaf", 1, 10),

        # Only OHE encodes features if the number of unique values will be <= the parameter vale.
        'one_hot_max_size': trial.suggest_categorical('one_hot_max_size', [5, 10, 12, 100]),

        # Class weights setting. Will also check if performance is better without weights
        'auto_class_weights': trial.suggest_categorical('auto_class_weights', ['Balanced', 'SqrtBalanced', 'None'])
    }

    # Certain parameters are "subparameters" and can only be set if their parent parameter has a certain value.

    # Bootstrap types
    if param['bootstrap_type'] == "Bayesian":

        # Use Baysesian bootstrapping to assign random weights to objects.
        param['bagging_temperature'] = trial.suggest_float('bagging_temperature', 0, 10)

    elif param['bootstrap_type'] in ['Bernoulli', 'MVS']:
        # Sample rate for bagging using Bernoulli/MVS type
        param['subsample'] = trial.suggest_float('subsample', 0.1, 1)

    # Grow policy params
    if param['grow_policy'] != 'SymmetricTree':

        # The minimum number of training samples in a leaf.
        param['min_data_in_leaf'] = trial.suggest_int('min_data_in_leaf', 1, 10)

        if param['grow_policy'] == 'LossGuide':
            # The maximum number of leafs in the tree.
            param['max_leaves'] = trial.suggest_int('max_leaves', 16, 64)

    # Creates the trial model with parameters specified above.
    trial_model = CatBoostClassifier(**param)

    # Fit the training model on training data
    trial_model.fit(X_train,
                    y_train,
                    eval_set=[(X_test, y_test)],
                    verbose=0,  # Stops Catboost from printing training results.
                    early_stopping_rounds=10  # Specify rounds of no improvement needed before stopping
                    )

    # Create predictions for test set
    preds = trial_model.predict(X_test)
    # Calculate recall score
    recall = recall_score(y_test, preds)

    return recall

# %%
# Instantiate a "trial" object and specify we want to MAXIMIZE the value being returned by the obj function
study = optuna.create_study(direction="maximize")

# Running 100 trials, setting a timeout value of 20 minutes to prevent my computer from exploding.
study.optimize(objective, n_trials=100, timeout=1200)

print("Number of finished trials: {}".format(len(study.trials)))
trial = study.best_trial

# "Prettify" our trial results
print("Best trial:")

# Print metric value achieved from best trial
print("  Value: {}".format(trial.value))

# Print all parameters from best trial
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2021-12-02 17:54:29,047] A new study created in memory with name: no-name-09a17641-3fbe-4d7d-b90f-df906b4fdd2d
# Training has stopped (degenerate solution on iteration 10, probably too small l2-regularization, try to increase it)
# [I 2021-12-02 17:54:59,268] Trial 0 finished with value: 0.46281464530892447 and parameters: {'iterations': 1000, 'learning_rate': 0.21370537586896476, 'l2_leaf_reg': 9.001843845541846e-07, 'bootstrap_type': 'Bayesian', 'random_strength': 3, 'max_bin': 5, 'max_depth': 15, 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 7, 'one_hot_max_size': 100, 'auto_class_weights': 'None', 'bagging_temperature': 1.7801662597062817}. Best is trial 0 with value: 0.46281464530892447.
# [I 2021-12-02 17:55:05,852] Trial 1 finished with value: 0.851258581235698 and parameters: {'iterations': 500, 'learning_rate': 0.22798586714156488, 'l2_leaf_reg': 0.00019224494694138002, 'bootstrap_type': 'MVS', 'random_strength': 10, 'max_bin': 8, 'max_depth': 11, 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 1, 'one_hot_max_size': 5, 'auto_class_weights': 'Balanced', 'subsample': 0.46841948073758477}. Best is trial 1 with value: 0.851258581235698.
# [I 2021-12-02 18:06:56,951] Trial 2 finished with value: 0.8747139588100686 and parameters: {'iterations': 1000, 'learning_rate': 0.12104783403055082, 'l2_leaf_reg': 88.87600479425672, 'bootstrap_type': 'Bernoulli', 'random_strength': 6, 'max_bin': 10, 'max_depth': 16, 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 1, 'one_hot_max_size': 10, 'auto_class_weights': 'Balanced', 'subsample': 0.17437778074804705}. Best is trial 2 with value: 0.8747139588100686.
# [I 2021-12-02 18:08:16,670] Trial 3 finished with value: 0.8953089244851259 and parameters: {'iterations': 500, 'learning_rate': 0.10249483382311927, 'l2_leaf_reg': 1.9211532938253748, 'bootstrap_type': 'Bayesian', 'random_strength': 2, 'max_bin': 4, 'max_depth': 6, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 10, 'one_hot_max_size': 5, 'auto_class_weights': 'Balanced', 'bagging_temperature': 9.056883317262889}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:08:35,732] Trial 4 finished with value: 0.8758581235697941 and parameters: {'iterations': 1000, 'learning_rate': 0.19742923972223414, 'l2_leaf_reg': 0.03712464036906359, 'bootstrap_type': 'Bernoulli', 'random_strength': 4, 'max_bin': 6, 'max_depth': 8, 'grow_policy': 'Depthwise', 'min_data_in_leaf': 4, 'one_hot_max_size': 100, 'auto_class_weights': 'Balanced', 'subsample': 0.7483058241315445}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:09:01,437] Trial 5 finished with value: 0.4954233409610984 and parameters: {'iterations': 300, 'learning_rate': 0.01302433088705571, 'l2_leaf_reg': 1.0306132775566521e-08, 'bootstrap_type': 'MVS', 'random_strength': 7, 'max_bin': 8, 'max_depth': 8, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 1, 'one_hot_max_size': 100, 'auto_class_weights': 'None', 'subsample': 0.33243689551713873}. Best is trial 3 with value: 0.8953089244851259.
# Training has stopped (degenerate solution on iteration 201, probably too small l2-regularization, try to increase it)
# [I 2021-12-02 18:09:32,089] Trial 6 finished with value: 0.7734553775743707 and parameters: {'iterations': 500, 'learning_rate': 0.0876088834194508, 'l2_leaf_reg': 0.00024095335664948606, 'bootstrap_type': 'Bernoulli', 'random_strength': 5, 'max_bin': 30, 'max_depth': 7, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 5, 'one_hot_max_size': 10, 'auto_class_weights': 'SqrtBalanced', 'subsample': 0.7439790032008057}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:10:11,676] Trial 7 finished with value: 0.7688787185354691 and parameters: {'iterations': 500, 'learning_rate': 0.15394983943855423, 'l2_leaf_reg': 26.677195061536473, 'bootstrap_type': 'Bernoulli', 'random_strength': 8, 'max_bin': 30, 'max_depth': 7, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 7, 'one_hot_max_size': 5, 'auto_class_weights': 'SqrtBalanced', 'subsample': 0.8466038003922594}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:10:49,480] Trial 8 finished with value: 0.6664759725400458 and parameters: {'iterations': 1000, 'learning_rate': 0.022615445580065213, 'l2_leaf_reg': 2.0300549124439102e-06, 'bootstrap_type': 'Bayesian', 'random_strength': 10, 'max_bin': 6, 'max_depth': 11, 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 10, 'one_hot_max_size': 5, 'auto_class_weights': 'SqrtBalanced', 'bagging_temperature': 3.0908880979879347}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:11:13,777] Trial 9 finished with value: 0.8890160183066361 and parameters: {'iterations': 500, 'learning_rate': 0.12150345535608138, 'l2_leaf_reg': 0.08701298871405722, 'bootstrap_type': 'Bernoulli', 'random_strength': 5, 'max_bin': 4, 'max_depth': 14, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 7, 'one_hot_max_size': 10, 'auto_class_weights': 'Balanced', 'subsample': 0.34584360430571726}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:11:21,706] Trial 10 finished with value: 0.8821510297482837 and parameters: {'iterations': 200, 'learning_rate': 0.27814821069995965, 'l2_leaf_reg': 0.8932088003530143, 'bootstrap_type': 'Bayesian', 'random_strength': 1, 'max_bin': 4, 'max_depth': 2, 'grow_policy': 'Depthwise', 'min_data_in_leaf': 10, 'one_hot_max_size': 12, 'auto_class_weights': 'Balanced', 'bagging_temperature': 8.749742519342776}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:11:30,492] Trial 11 finished with value: 0.8421052631578947 and parameters: {'iterations': 100, 'learning_rate': 0.08254685300490117, 'l2_leaf_reg': 0.06018528138324224, 'bootstrap_type': 'Bayesian', 'random_strength': 1, 'max_bin': 4, 'max_depth': 3, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 8, 'one_hot_max_size': 10, 'auto_class_weights': 'Balanced', 'bagging_temperature': 9.91879108482411}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:11:46,775] Trial 12 finished with value: 0.8953089244851259 and parameters: {'iterations': 500, 'learning_rate': 0.1431756957511237, 'l2_leaf_reg': 0.6759423169633468, 'bootstrap_type': 'Bernoulli', 'random_strength': 3, 'max_bin': 4, 'max_depth': 13, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 9, 'one_hot_max_size': 12, 'auto_class_weights': 'Balanced', 'subsample': 0.1294088720602255}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:13:04,802] Trial 13 finished with value: 0.8792906178489702 and parameters: {'iterations': 500, 'learning_rate': 0.06649122693161476, 'l2_leaf_reg': 2.6781875188667983, 'bootstrap_type': 'Bayesian', 'random_strength': 3, 'max_bin': 20, 'max_depth': 5, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 9, 'one_hot_max_size': 12, 'auto_class_weights': 'Balanced', 'bagging_temperature': 6.547558605222038}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:13:11,414] Trial 14 finished with value: 0.6115560640732265 and parameters: {'iterations': 100, 'learning_rate': 0.16371826644562215, 'l2_leaf_reg': 0.0054209044761142555, 'bootstrap_type': 'MVS', 'random_strength': 2, 'max_bin': 4, 'max_depth': 12, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 9, 'one_hot_max_size': 12, 'auto_class_weights': 'None', 'subsample': 0.14210147902442433}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:13:45,585] Trial 15 finished with value: 0.8930205949656751 and parameters: {'iterations': 200, 'learning_rate': 0.12055126855058594, 'l2_leaf_reg': 1.481054234890021, 'bootstrap_type': 'Bernoulli', 'random_strength': 3, 'max_bin': 4, 'max_depth': 5, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 3, 'one_hot_max_size': 5, 'auto_class_weights': 'Balanced', 'subsample': 0.9756044965447372}. Best is trial 3 with value: 0.8953089244851259.
# [I 2021-12-02 18:14:45,276] Trial 16 finished with value: 0.8295194508009154 and parameters: {'iterations': 300, 'learning_rate': 0.0486399746233661, 'l2_leaf_reg': 0.002870968848173471, 'bootstrap_type': 'Bayesian', 'random_strength': 2, 'max_bin': 20, 'max_depth': 13, 'grow_policy': 'Depthwise', 'min_data_in_leaf': 9, 'one_hot_max_size': 12, 'auto_class_weights': 'Balanced', 'bagging_temperature': 5.960357435743283}. Best is trial 3 with value: 0.8953089244851259.
# Number of finished trials: 17
# Best trial:
#   Value: 0.8953089244851259
#   Params:
#     iterations: 500
#     learning_rate: 0.10249483382311927
#     l2_leaf_reg: 1.9211532938253748
#     bootstrap_type: Bayesian
#     random_strength: 2
#     max_bin: 4
#     max_depth: 6
#     grow_policy: Lossguide
#     min_data_in_leaf: 10
#     one_hot_max_size: 5
#     auto_class_weights: Balanced
#     bagging_temperature: 9.056883317262889

# %%
# Create a model with the parameters from our best trial
final_model = CatBoostClassifier(verbose=False, **trial.params)
final_model.fit(X_train, y_train)

# %% [markdown]
# # Results
#  Before performing analysis let's look at the results, the confusion matrix, and the ROC Curve.

# %%
# Importing required packages for this section
from sklearn.metrics import RocCurveDisplay

# %%
# Show custom metrics
from functions import metrics as custom_score
final_results = custom_score(X_test, y_test, final_model)
# Out:
# Model Results
# Accuracy: 0.90
# Precision: 0.47
# Recall: 0.89
# F1: 0.61
# ROC AUC: 0.96

# %%
# Printing the difference between the oversample model, and the tuned oversample model.
print('Difference between Tuned Model and Un-tuned Model')
custom_change(FSM_results, final_results)
# Out:
# Difference between Tuned Model and Un-tuned Model
# Change in Results
# Accuracy        -0.05
# Precision       -0.29
# Recall          +0.28
# F1              -0.07
# ROCAUC          -0.00

# %%
# Creating a confusion matrix for the final model
final_matrix = ConfusionMatrixDisplay.from_predictions(y_test, final_model.predict(X_test), cmap='Reds')

# %%
# Using sklearn function to plot ROC curve from model & data
final_roc_curve = RocCurveDisplay.from_estimator(estimator=final_model, X=X_test, y=y_test)

# %% [markdown]
# ## Analysis
# I chose to optimize on ROC score here, since I'm planning on using the predicted probabilities that a person has undiagnosed ADHD. We gained recall and AUC, however we lost more precision after tuning. We can see that the test set only missed **133 kids** that were diagnosed with ADHD.
#
# I would say this is the prefered scenario. If a child is identified as having undiagnosed ADHD, and they don't, then the worst that would happen is they'd see a doctor and have their worries put to rest. However, if the model says a child doesn't have ADHD, and later they **do** have ADHD, then that means more time, frustration, and confusion before they get diagnosed. Not even to mention the frustration of being told that you don't have ADHD, only to find out later that you do.
#
# ## Hold-out / Validation Dataset
# Now it's time to do the final test on our model. Time to score it on the validation set.

# %%
X_val = pd.read_csv('../Data/val/X_val_combo.csv', index_col=0)
y_val = pd.read_csv('../Data/val/y_val_combo.csv', index_col=0)

X_val.drop(columns=summary['eliminated_features_names'], inplace=True)

# %%
validation_scores = custom_score(X_val, y_val, final_model)
# Out:
# Model Results
# Accuracy: 0.90
# Precision: 0.47
# Recall: 0.90
# F1: 0.61
# ROC AUC: 0.96

# %%
# Save the final model
# final_model.save_model('../Model/final_model.cbm', format='cbm')

# %% [markdown]
# The final model has an **accuracy of 0.90** -in other words, **the model correctly classifies all children in the set 90% of the time**
#
# The final model has a **precision of 0.47** —in other words, **when it predicts a child is diagnosed with ADHD, it is correct 47% of the time**.
#
# The final model has a **recall of 0.90** —in other words, **it correctly identifies 90% of all children diagnosed with ADHD**.

# %% [markdown]
# # Conclusion
# This final model could be used with the survey each year, and the kids who the model flagged as having a high chance of undiagnosed ADHD would then have an email sent to their primary caregiver. The email could then explain that their child shows many similarities with those who have been diagnosed with ADHD. Resources for ADHD and recommendations on next steps could be included in the email as well.
#
# If the survey administrators don't want this, there is still value in this model. I've shown that it's possible to use machine learning to accurately identify kids with ADHD. Not only this, but I've shown it's possible to do this with just survey data, and if you can identify ADHD using survey data, it could be possible to identify other conditions, like depression, anxiety, and autism as well.
#
# Finally, I've used real data to build this model. The model has learned what kids with ADHD may look like, and has used that knowledge to identify others. If this were to be deployed, it could serve as a tool for those seeking answers, but unable to see a doctor to get an offical diagnoses. Certainly better then a quiz on a random website that has no scientific basis at all.

# %% [markdown]
# # Next Steps
# Moving forward, I'd like to deploy this model in such a way that others can interact with it. Deploying this to a website and allowing people to answer the same questions on the survey would be a great way to show the capabilities of the model.
#
# I'm sure the model can be improved in other ways as well, as well as be adapted to identify other types of developmental disorders.
#
# Finally, if at all possible, I'd love to have the coroporation of the survey administrators and work on using this model with their next survey.
